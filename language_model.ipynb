# %% [markdown]
# #Testing on CoLA Dataset

# %%
# !pip install datasets
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.11.0-py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.7/468.7 kB 4.3 MB/s eta 0:00:00
# Collecting dill<0.3.7,>=0.3.0
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from datasets) (1.22.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (2.27.1)
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 21.6 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (6.0)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from datasets) (23.0)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (2023.3.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from datasets) (1.5.3)
# Collecting huggingface-hub<1.0.0,>=0.11.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 8.9 MB/s eta 0:00:00
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 kB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (4.65.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (9.0.0)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (2.0.12)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (22.2.0)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 8.5 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (3.11.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (1.26.15)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, multidict, frozenlist, dill, async-timeout, yarl, responses, multiprocess, huggingface-hub, aiosignal, aiohttp, datasets
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.11.0 dill-0.3.6 frozenlist-1.3.3 huggingface-hub-0.13.4 multidict-6.0.4 multiprocess-0.70.14 responses-0.18.0 xxhash-3.2.0 yarl-1.8.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.27.4-py3-none-any.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 19.2 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 61.2 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (0.13.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.11.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Installing collected packages: tokenizers, transformers
# Successfully installed tokenizers-0.13.3 transformers-4.27.4

# %%
from datasets import load_dataset
data = load_dataset("glue", "cola")
unlabelled_dataset=data['train']['sentence'][:850]

# %%
from transformers import BertTokenizer

tokenizer = BertTokenizer.from_pretrained('bert-base-cased')

# Tokenize the unlabelled data
tokenized_data = [tokenizer.encode(text, add_special_tokens=True) for text in unlabelled_dataset]

# %%
import random

# Mask a random percentage of tokens in each sequence
masked_data = []
for sequence in tokenized_data:
    masked_sequence = sequence.copy()
    num_masks = int(len(sequence) * 0.15)  # Mask 15% of the tokens
    indices = random.sample(range(1, len(sequence) - 1), num_masks)  # Exclude special tokens [CLS] and [SEP]
    for index in indices:
        if random.random() < 0.8:  # 80% of the time, replace the token with [MASK]
            masked_sequence[index] = tokenizer.mask_token_id
        elif random.random() < 0.5:  # 10% of the time, replace the token with a random token
            masked_sequence[index] = random.randint(0, len(tokenizer) - 1)
    masked_data.append(masked_sequence)

# %%
import torch

# %%
# Set the maximum sequence length
max_length = 512

# Pad the sequences that are shorter than max_length
padded_data = []
for sequence in masked_data:
    if len(sequence) < max_length:
        sequence += [tokenizer.pad_token_id] * (max_length - len(sequence))
    padded_data.append(sequence)

# Convert the padded data to PyTorch tensors
input_ids = torch.tensor(padded_data)

# %%
import torch
from transformers import BertTokenizer, BertForMaskedLM
from torch.optim import AdamW
from tqdm import tqdm  # Import tqdm for the progress bar

# Load the tokenizer and model
tokenizer = BertTokenizer.from_pretrained("bert-base-cased")
model = BertForMaskedLM.from_pretrained("bert-base-cased")
device = torch.device("cuda")
model.to(device)

# Define the optimizer
optimizer = AdamW(model.parameters(), lr=5e-5)

# Loop through the data by batch
for epoch in range(1):
    for batch in tqdm(input_ids):  # Add tqdm to loop for progress bar
        batch = batch.to(device)  # Move the batch to the GPU

        # Set 15% of tokens to be masked
        mask_indices = torch.bernoulli(torch.full(batch.shape, 0.15)).bool()
        batch[mask_indices] = tokenizer.mask_token_id

        # Set another 15% of tokens to be randomly replaced
        random_indices = torch.bernoulli(torch.full(batch.shape, 0.15)).bool() & ~mask_indices
        random_tokens = torch.randint(len(tokenizer), batch.shape, dtype=torch.long).to(device)  # Move to the GPU
        batch[random_indices] = random_tokens[random_indices]

        # Clear gradients and compute forward pass
        optimizer.zero_grad()
        loss = model(input_ids=batch.unsqueeze(0), labels=batch.unsqueeze(0))[0]

        # Backpropagate the loss and update the weights
        loss.backward()
        optimizer.step()

# %%
# Input a sentence
sentence = "The quick brown fox jumps over the lazy dog."

# Tokenize the sentence
tokens = tokenizer.tokenize(sentence)

# Mask a random token in the sentence
masked_index = torch.randint(len(tokens), (1,)).item()
tokens[masked_index] = tokenizer.mask_token

# Convert tokens to input_ids
input_ids = torch.tensor([tokenizer.convert_tokens_to_ids(tokens)])

# Move input_ids to the GPU
input_ids = input_ids.to(device)

# Get the model's predictions
with torch.no_grad():
    outputs = model(input_ids)
    predictions = outputs[0]

# Get the predicted token for the masked position
predicted_index = torch.argmax(predictions[0, masked_index]).item()
predicted_token = tokenizer.convert_ids_to_tokens([predicted_index])[0]

# Print the original sentence, masked sentence, and predicted token
print("Original sentence:", sentence)
print("Masked sentence:", tokenizer.convert_tokens_to_string(tokens))
print("Predicted token:", predicted_token)

# %%
# Ask a question
question = "hello"
question_tokens = tokenizer.tokenize(question)
question_ids = torch.tensor([tokenizer.convert_tokens_to_ids(question_tokens)])

# Move question_ids to the GPU
question_ids = question_ids.to(device)

# Get the model's predictions for the question
with torch.no_grad():
    outputs = model(input_ids=question_ids)
    predictions = outputs[0]

# Get the predicted token for the masked position
predicted_index = torch.argmax(predictions[0, -1]).item()
predicted_token = tokenizer.convert_ids_to_tokens([predicted_index])[0]

# Print the question and predicted answer
print("Question:", question)
print("Answer:", predicted_token)

# %%
import tensorflow as tf
tf.keras.backend.clear_session()

# %% [markdown]
# #Slips Preprocess document files

# %%
import requests
import zipfile
import io
import os

if not(os.path.exists('master.zip')):
    # !wget https://github.com/stratosphereips/StratosphereLinuxIPS/archive/refs/heads/master.zip
    # !unzip master.zip

    import shutil

    # Define the path of the docs folder
    docs_folder = "StratosphereLinuxIPS-master/docs"

    # Move the docs folder to the current working directory
    shutil.move(docs_folder, ".")
# Out:
# --2023-04-13 15:00:17--  https://github.com/stratosphereips/StratosphereLinuxIPS/archive/refs/heads/master.zip
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/stratosphereips/StratosphereLinuxIPS/zip/refs/heads/master [following]
# --2023-04-13 15:00:17--  https://codeload.github.com/stratosphereips/StratosphereLinuxIPS/zip/refs/heads/master
# Resolving codeload.github.com (codeload.github.com)... 140.82.112.9
# Connecting to codeload.github.com (codeload.github.com)|140.82.112.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘master.zip’
#
# master.zip              [        <=>         ]  19.47M  8.46MB/s    in 2.3s
#
# 2023-04-13 15:00:20 (8.46 MB/s) - ‘master.zip’ saved [20414766]
#
# Archive:  master.zip
# 99d9c3b725a4ab6b754f3a4f87085f09edc64ab5
#    creating: StratosphereLinuxIPS-master/
#   inflating: StratosphereLinuxIPS-master/.dockerignore
#    creating: StratosphereLinuxIPS-master/.github/
#    creating: StratosphereLinuxIPS-master/.github/ISSUE_TEMPLATE/
#   inflating: StratosphereLinuxIPS-master/.github/ISSUE_TEMPLATE/bug_report.md
#   inflating: StratosphereLinuxIPS-master/.github/ISSUE_TEMPLATE/feature-request-template.md
#   inflating: StratosphereLinuxIPS-master/.github/pull_request_template.md
#    creating: StratosphereLinuxIPS-master/.github/workflows/
#   inflating: StratosphereLinuxIPS-master/.github/workflows/CI-production-testing.yml
#   inflating: StratosphereLinuxIPS-master/.github/workflows/CI-publishing.yml
#   inflating: StratosphereLinuxIPS-master/.github/workflows/CI-staging.yml
#   inflating: StratosphereLinuxIPS-master/.gitignore
#   inflating: StratosphereLinuxIPS-master/.gitmodules
#   inflating: StratosphereLinuxIPS-master/.readthedocs.yaml
#   inflating: StratosphereLinuxIPS-master/CHANGELOG.md
#   inflating: StratosphereLinuxIPS-master/CITATION.cff
#   inflating: StratosphereLinuxIPS-master/LICENCE
#   inflating: StratosphereLinuxIPS-master/Makefile
#   inflating: StratosphereLinuxIPS-master/README.md
#  extracting: StratosphereLinuxIPS-master/VERSION
#  extracting: StratosphereLinuxIPS-master/__init__.py
#   inflating: StratosphereLinuxIPS-master/conda-environment.yaml
#    creating: StratosphereLinuxIPS-master/config/
#   inflating: StratosphereLinuxIPS-master/config/JA3_feeds.csv
#  extracting: StratosphereLinuxIPS-master/config/RiskIQ_credentials
#   inflating: StratosphereLinuxIPS-master/config/SSL_feeds.csv
#   inflating: StratosphereLinuxIPS-master/config/TI_feeds.csv
#    creating: StratosphereLinuxIPS-master/config/local_ti_files/
#   inflating: StratosphereLinuxIPS-master/config/local_ti_files/own_malicious_JA3.csv
#   inflating: StratosphereLinuxIPS-master/config/local_ti_files/own_malicious_iocs.csv
#   inflating: StratosphereLinuxIPS-master/config/logstash.conf
#  extracting: StratosphereLinuxIPS-master/config/slack_bot_token_secret
#   inflating: StratosphereLinuxIPS-master/config/slips.conf
#  extracting: StratosphereLinuxIPS-master/config/vt_api_key
#   inflating: StratosphereLinuxIPS-master/config/warden.conf
#   inflating: StratosphereLinuxIPS-master/config/whitelist.conf
#   inflating: StratosphereLinuxIPS-master/conftest.py
#   inflating: StratosphereLinuxIPS-master/daemon.py
#    creating: StratosphereLinuxIPS-master/databases/
#   inflating: StratosphereLinuxIPS-master/databases/GeoLite2-ASN.mmdb
#   inflating: StratosphereLinuxIPS-master/databases/GeoLite2-Country.mmdb
#    creating: StratosphereLinuxIPS-master/dataset/
#   inflating: StratosphereLinuxIPS-master/dataset/test1-normal.nfdump
#    creating: StratosphereLinuxIPS-master/dataset/test10-mixed-zeek-dir/
#   inflating: StratosphereLinuxIPS-master/dataset/test10-mixed-zeek-dir/capture_loss.log
#   inflating: StratosphereLinuxIPS-master/dataset/test10-mixed-zeek-dir/conn.log
#   inflating: StratosphereLinuxIPS-master/dataset/test10-mixed-zeek-dir/dns.log
#   inflating: StratosphereLinuxIPS-master/dataset/test10-mixed-zeek-dir/files.log
#   inflating: StratosphereLinuxIPS-master/dataset/test10-mixed-zeek-dir/loaded_scripts.log
#   inflating: StratosphereLinuxIPS-master/dataset/test10-mixed-zeek-dir/notice.log
#   inflating: StratosphereLinuxIPS-master/dataset/test10-mixed-zeek-dir/packet_filter.log
#   inflating: StratosphereLinuxIPS-master/dataset/test10-mixed-zeek-dir/reporter.log
#   inflating: StratosphereLinuxIPS-master/dataset/test10-mixed-zeek-dir/ssl.log
#   inflating: StratosphereLinuxIPS-master/dataset/test10-mixed-zeek-dir/weird.log
#   inflating: StratosphereLinuxIPS-master/dataset/test10-mixed-zeek-dir/x509.log
#   inflating: StratosphereLinuxIPS-master/dataset/test11-portscan.binetflow
#   inflating: StratosphereLinuxIPS-master/dataset/test12-icmp-portscan.pcap
#    creating: StratosphereLinuxIPS-master/dataset/test13-malicious-dhcpscan-zeek-dir/
#   inflating: StratosphereLinuxIPS-master/dataset/test13-malicious-dhcpscan-zeek-dir/conn.log
#   inflating: StratosphereLinuxIPS-master/dataset/test13-malicious-dhcpscan-zeek-dir/dhcp.log
#    creating: StratosphereLinuxIPS-master/dataset/test14-malicious-zeek-dir/
#   inflating: StratosphereLinuxIPS-master/dataset/test14-malicious-zeek-dir/http.log
#   inflating: StratosphereLinuxIPS-master/dataset/test14-malicious-zeek-dir/smtp.log
#    creating: StratosphereLinuxIPS-master/dataset/test15-malicious-zeek-dir/
#   inflating: StratosphereLinuxIPS-master/dataset/test15-malicious-zeek-dir/software.log
#   inflating: StratosphereLinuxIPS-master/dataset/test15-malicious-zeek-dir/ssl.log
#    creating: StratosphereLinuxIPS-master/dataset/test16-malicious-zeek-dir/
#   inflating: StratosphereLinuxIPS-master/dataset/test16-malicious-zeek-dir/arp.log
#   inflating: StratosphereLinuxIPS-master/dataset/test2-malicious.binetflow
#   inflating: StratosphereLinuxIPS-master/dataset/test3-mixed.binetflow
#   inflating: StratosphereLinuxIPS-master/dataset/test4-malicious.binetflow
#   inflating: StratosphereLinuxIPS-master/dataset/test5-mixed.binetflow
#   inflating: StratosphereLinuxIPS-master/dataset/test6-malicious.suricata.json
#   inflating: StratosphereLinuxIPS-master/dataset/test7-malicious.pcap
#   inflating: StratosphereLinuxIPS-master/dataset/test8-malicious.pcap
#    creating: StratosphereLinuxIPS-master/dataset/test9-mixed-zeek-dir/
#   inflating: StratosphereLinuxIPS-master/dataset/test9-mixed-zeek-dir/arp.log
#   inflating: StratosphereLinuxIPS-master/dataset/test9-mixed-zeek-dir/conn.log
#   inflating: StratosphereLinuxIPS-master/dataset/test9-mixed-zeek-dir/dhcp.log
#   inflating: StratosphereLinuxIPS-master/dataset/test9-mixed-zeek-dir/dns.log
#   inflating: StratosphereLinuxIPS-master/dataset/test9-mixed-zeek-dir/files.log
#   inflating: StratosphereLinuxIPS-master/dataset/test9-mixed-zeek-dir/http.log
#   inflating: StratosphereLinuxIPS-master/dataset/test9-mixed-zeek-dir/loaded_scripts.log
#   inflating: StratosphereLinuxIPS-master/dataset/test9-mixed-zeek-dir/notice.log
#   inflating: StratosphereLinuxIPS-master/dataset/test9-mixed-zeek-dir/packet_filter.log
#   inflating: StratosphereLinuxIPS-master/dataset/test9-mixed-zeek-dir/pe.log
#   inflating: StratosphereLinuxIPS-master/dataset/test9-mixed-zeek-dir/smtp.log
#   inflating: StratosphereLinuxIPS-master/dataset/test9-mixed-zeek-dir/software.log
#   inflating: StratosphereLinuxIPS-master/dataset/test9-mixed-zeek-dir/ssl.log
#   inflating: StratosphereLinuxIPS-master/dataset/test9-mixed-zeek-dir/weird.log
#   inflating: StratosphereLinuxIPS-master/dataset/test9-mixed-zeek-dir/x509.log
#    creating: StratosphereLinuxIPS-master/docker/
#    creating: StratosphereLinuxIPS-master/docker/P2P-image/
#   inflating: StratosphereLinuxIPS-master/docker/P2P-image/Dockerfile
#    creating: StratosphereLinuxIPS-master/docker/dependency-image/
#   inflating: StratosphereLinuxIPS-master/docker/dependency-image/Dockerfile
#   inflating: StratosphereLinuxIPS-master/docker/docker-compose.yml
#    creating: StratosphereLinuxIPS-master/docker/macosm1-P2P-image/
#   inflating: StratosphereLinuxIPS-master/docker/macosm1-P2P-image/Dockerfile
#   inflating: StratosphereLinuxIPS-master/docker/macosm1-P2P-image/requirements-macos-m1-docker.txt
#    creating: StratosphereLinuxIPS-master/docker/macosm1-image/
#   inflating: StratosphereLinuxIPS-master/docker/macosm1-image/Dockerfile
#   inflating: StratosphereLinuxIPS-master/docker/macosm1-image/requirements-macos-m1-docker.txt
#    creating: StratosphereLinuxIPS-master/docker/tensorflow-image/
#   inflating: StratosphereLinuxIPS-master/docker/tensorflow-image/Dockerfile
#    creating: StratosphereLinuxIPS-master/docker/ubuntu-image/
#   inflating: StratosphereLinuxIPS-master/docker/ubuntu-image/Dockerfile
#   inflating: StratosphereLinuxIPS-master/docker/ubuntu-image/docker-compose.yml
#    creating: StratosphereLinuxIPS-master/docs/
#   inflating: StratosphereLinuxIPS-master/docs/FAQ.md
#   inflating: StratosphereLinuxIPS-master/docs/Makefile
#   inflating: StratosphereLinuxIPS-master/docs/P2P.md
#   inflating: StratosphereLinuxIPS-master/docs/architecture.md
#   inflating: StratosphereLinuxIPS-master/docs/code_documentation.md
#   inflating: StratosphereLinuxIPS-master/docs/conf.py
#   inflating: StratosphereLinuxIPS-master/docs/contributing.md
#   inflating: StratosphereLinuxIPS-master/docs/create_new_module.md
#   inflating: StratosphereLinuxIPS-master/docs/detection_modules.md
#   inflating: StratosphereLinuxIPS-master/docs/exporting.md
#   inflating: StratosphereLinuxIPS-master/docs/features.md
#   inflating: StratosphereLinuxIPS-master/docs/flowalerts.md
#    creating: StratosphereLinuxIPS-master/docs/images/
#   inflating: StratosphereLinuxIPS-master/docs/images/alerts_log.png
#   inflating: StratosphereLinuxIPS-master/docs/images/directions.png
#   inflating: StratosphereLinuxIPS-master/docs/images/droidjack_alert.png
#   inflating: StratosphereLinuxIPS-master/docs/images/emotet_alerts.png
#   inflating: StratosphereLinuxIPS-master/docs/images/expanding_infected_timewindow.png
#   inflating: StratosphereLinuxIPS-master/docs/images/kalipso.png
#   inflating: StratosphereLinuxIPS-master/docs/images/kalispo_infected_tw.png
#   inflating: StratosphereLinuxIPS-master/docs/images/module.gif
#   inflating: StratosphereLinuxIPS-master/docs/images/modules_starting.png
#   inflating: StratosphereLinuxIPS-master/docs/images/qakbot.png
#   inflating: StratosphereLinuxIPS-master/docs/images/saefko_first_alert.png
#   inflating: StratosphereLinuxIPS-master/docs/images/slips.gif
#   inflating: StratosphereLinuxIPS-master/docs/images/slips_internal_architecture.jpg
#   inflating: StratosphereLinuxIPS-master/docs/images/slips_logo.png
#   inflating: StratosphereLinuxIPS-master/docs/images/slips_workflow.png
#   inflating: StratosphereLinuxIPS-master/docs/images/trickbot.png
#   inflating: StratosphereLinuxIPS-master/docs/images/updating_remote_feeds.png
#   inflating: StratosphereLinuxIPS-master/docs/images/web_interface.png
#   inflating: StratosphereLinuxIPS-master/docs/index.rst
#   inflating: StratosphereLinuxIPS-master/docs/installation.md
#   inflating: StratosphereLinuxIPS-master/docs/make.bat
#   inflating: StratosphereLinuxIPS-master/docs/slips_in_action.md
#   inflating: StratosphereLinuxIPS-master/docs/training.md
#   inflating: StratosphereLinuxIPS-master/docs/usage.md
#   inflating: StratosphereLinuxIPS-master/install.sh
#   inflating: StratosphereLinuxIPS-master/kalipso.sh
#    creating: StratosphereLinuxIPS-master/modules/
#    creating: StratosphereLinuxIPS-master/modules/CESNET/
#   inflating: StratosphereLinuxIPS-master/modules/CESNET/CESNET.py
#   inflating: StratosphereLinuxIPS-master/modules/CESNET/__init__.py
#   inflating: StratosphereLinuxIPS-master/modules/CESNET/warden_client.py
#    creating: StratosphereLinuxIPS-master/modules/RiskIQ/
#   inflating: StratosphereLinuxIPS-master/modules/RiskIQ/RiskIQ.py
#   inflating: StratosphereLinuxIPS-master/modules/RiskIQ/__init__.py
#   inflating: StratosphereLinuxIPS-master/modules/__init__.py
#    creating: StratosphereLinuxIPS-master/modules/arp/
#   inflating: StratosphereLinuxIPS-master/modules/arp/__init__.py
#   inflating: StratosphereLinuxIPS-master/modules/arp/arp.py
#    creating: StratosphereLinuxIPS-master/modules/blocking/
#   inflating: StratosphereLinuxIPS-master/modules/blocking/__init__.py
#   inflating: StratosphereLinuxIPS-master/modules/blocking/blocking.py
#    creating: StratosphereLinuxIPS-master/modules/ensembling/
#   inflating: StratosphereLinuxIPS-master/modules/ensembling/__init__.py
#   inflating: StratosphereLinuxIPS-master/modules/ensembling/ensembling.py
#    creating: StratosphereLinuxIPS-master/modules/exporting_alerts/
#   inflating: StratosphereLinuxIPS-master/modules/exporting_alerts/__init__.py
#   inflating: StratosphereLinuxIPS-master/modules/exporting_alerts/exporting_alerts.py
#    creating: StratosphereLinuxIPS-master/modules/flowalerts/
#   inflating: StratosphereLinuxIPS-master/modules/flowalerts/TimerThread.py
#   inflating: StratosphereLinuxIPS-master/modules/flowalerts/__init__.py
#   inflating: StratosphereLinuxIPS-master/modules/flowalerts/flowalerts.py
#   inflating: StratosphereLinuxIPS-master/modules/flowalerts/set_evidence.py
#    creating: StratosphereLinuxIPS-master/modules/flowmldetection/
#   inflating: StratosphereLinuxIPS-master/modules/flowmldetection/__init__.py
#   inflating: StratosphereLinuxIPS-master/modules/flowmldetection/flowmldetection.py
#   inflating: StratosphereLinuxIPS-master/modules/flowmldetection/model.bin
#   inflating: StratosphereLinuxIPS-master/modules/flowmldetection/scaler.bin
#    creating: StratosphereLinuxIPS-master/modules/http_analyzer/
#   inflating: StratosphereLinuxIPS-master/modules/http_analyzer/__init__.py
#   inflating: StratosphereLinuxIPS-master/modules/http_analyzer/http_analyzer.py
#    creating: StratosphereLinuxIPS-master/modules/ip_info/
#   inflating: StratosphereLinuxIPS-master/modules/ip_info/__init__.py
#   inflating: StratosphereLinuxIPS-master/modules/ip_info/asn_info.py
#   inflating: StratosphereLinuxIPS-master/modules/ip_info/ip_info.py
#    creating: StratosphereLinuxIPS-master/modules/kalipso/
#   inflating: StratosphereLinuxIPS-master/modules/kalipso/README.md
#   inflating: StratosphereLinuxIPS-master/modules/kalipso/countries.json
#   inflating: StratosphereLinuxIPS-master/modules/kalipso/kalipso.js
#    creating: StratosphereLinuxIPS-master/modules/kalipso/kalipso_widgets/
#   inflating: StratosphereLinuxIPS-master/modules/kalipso/kalipso_widgets/database.js
#   inflating: StratosphereLinuxIPS-master/modules/kalipso/kalipso_widgets/evidence.js
#   inflating: StratosphereLinuxIPS-master/modules/kalipso/kalipso_widgets/help.js
#   inflating: StratosphereLinuxIPS-master/modules/kalipso/kalipso_widgets/intuples.js
#   inflating: StratosphereLinuxIPS-master/modules/kalipso/kalipso_widgets/ipinfo.js
#   inflating: StratosphereLinuxIPS-master/modules/kalipso/kalipso_widgets/kalipso_connect_listtable_gauge.js
#   inflating: StratosphereLinuxIPS-master/modules/kalipso/kalipso_widgets/libraries.js
#   inflating: StratosphereLinuxIPS-master/modules/kalipso/kalipso_widgets/outtuples.js
#   inflating: StratosphereLinuxIPS-master/modules/kalipso/kalipso_widgets/profile_evidences.js
#   inflating: StratosphereLinuxIPS-master/modules/kalipso/kalipso_widgets/profile_tws.js
#   inflating: StratosphereLinuxIPS-master/modules/kalipso/kalipso_widgets/screen.js
#   inflating: StratosphereLinuxIPS-master/modules/kalipso/kalipso_widgets/timeline.js
#    creating: StratosphereLinuxIPS-master/modules/kalipso/lib_widgets/
#   inflating: StratosphereLinuxIPS-master/modules/kalipso/lib_widgets/box.js
#   inflating: StratosphereLinuxIPS-master/modules/kalipso/lib_widgets/gauge.js
#   inflating: StratosphereLinuxIPS-master/modules/kalipso/lib_widgets/listbar.js
#   inflating: StratosphereLinuxIPS-master/modules/kalipso/lib_widgets/listtable.js
#   inflating: StratosphereLinuxIPS-master/modules/kalipso/lib_widgets/table.js
#   inflating: StratosphereLinuxIPS-master/modules/kalipso/lib_widgets/tree.js
#   inflating: StratosphereLinuxIPS-master/modules/kalipso/package-lock.json
#   inflating: StratosphereLinuxIPS-master/modules/kalipso/package.json
#    creating: StratosphereLinuxIPS-master/modules/leak_detector/
#   inflating: StratosphereLinuxIPS-master/modules/leak_detector/__init__.py
#   inflating: StratosphereLinuxIPS-master/modules/leak_detector/leak_detector.py
#    creating: StratosphereLinuxIPS-master/modules/leak_detector/yara_rules/
#    creating: StratosphereLinuxIPS-master/modules/leak_detector/yara_rules/rules/
#   inflating: StratosphereLinuxIPS-master/modules/leak_detector/yara_rules/rules/GPS_leaks.yara
#    creating: StratosphereLinuxIPS-master/modules/network_discovery/
#  extracting: StratosphereLinuxIPS-master/modules/network_discovery/__init__.py
#   inflating: StratosphereLinuxIPS-master/modules/network_discovery/network_discovery.py
#    creating: StratosphereLinuxIPS-master/modules/p2ptrust/
#  extracting: StratosphereLinuxIPS-master/modules/p2ptrust/__init__.py
#   inflating: StratosphereLinuxIPS-master/modules/p2ptrust/data_format.md
#   inflating: StratosphereLinuxIPS-master/modules/p2ptrust/p2ptrust.py
#    creating: StratosphereLinuxIPS-master/modules/p2ptrust/testing/
#  extracting: StratosphereLinuxIPS-master/modules/p2ptrust/testing/__init__.py
#   inflating: StratosphereLinuxIPS-master/modules/p2ptrust/testing/json_data.py
#   inflating: StratosphereLinuxIPS-master/modules/p2ptrust/testing/test_p2p.py
#    creating: StratosphereLinuxIPS-master/modules/p2ptrust/trust/
#  extracting: StratosphereLinuxIPS-master/modules/p2ptrust/trust/__init__.py
#   inflating: StratosphereLinuxIPS-master/modules/p2ptrust/trust/base_model.py
#   inflating: StratosphereLinuxIPS-master/modules/p2ptrust/trust/model.py
#   inflating: StratosphereLinuxIPS-master/modules/p2ptrust/trust/trustdb.py
#    creating: StratosphereLinuxIPS-master/modules/p2ptrust/utils/
#  extracting: StratosphereLinuxIPS-master/modules/p2ptrust/utils/__init__.py
#   inflating: StratosphereLinuxIPS-master/modules/p2ptrust/utils/go_director.py
#   inflating: StratosphereLinuxIPS-master/modules/p2ptrust/utils/printer.py
#   inflating: StratosphereLinuxIPS-master/modules/p2ptrust/utils/utils.py
#    creating: StratosphereLinuxIPS-master/modules/rnn-cc-detection/
#   inflating: StratosphereLinuxIPS-master/modules/rnn-cc-detection/LICENSE
#   inflating: StratosphereLinuxIPS-master/modules/rnn-cc-detection/README.md
#   inflating: StratosphereLinuxIPS-master/modules/rnn-cc-detection/__init__.py
#    creating: StratosphereLinuxIPS-master/modules/rnn-cc-detection/datasets/
#   inflating: StratosphereLinuxIPS-master/modules/rnn-cc-detection/datasets/all_datasets_raw
#   inflating: StratosphereLinuxIPS-master/modules/rnn-cc-detection/datasets/all_datasets_raw_v2
#   inflating: StratosphereLinuxIPS-master/modules/rnn-cc-detection/datasets/all_datasets_raw_v3
#   inflating: StratosphereLinuxIPS-master/modules/rnn-cc-detection/datasets/dataset22
#   inflating: StratosphereLinuxIPS-master/modules/rnn-cc-detection/datasets/dataset45
#   inflating: StratosphereLinuxIPS-master/modules/rnn-cc-detection/datasets/dataset66
#   inflating: StratosphereLinuxIPS-master/modules/rnn-cc-detection/datasets/dataset87.dat
#   inflating: StratosphereLinuxIPS-master/modules/rnn-cc-detection/datasets/dataset_dga_raw
#   inflating: StratosphereLinuxIPS-master/modules/rnn-cc-detection/datasets/dataset_more_labels.dat
#   inflating: StratosphereLinuxIPS-master/modules/rnn-cc-detection/datasets/letter-assignment-behavioral-models.png
#   inflating: StratosphereLinuxIPS-master/modules/rnn-cc-detection/rnn-cc-detection.py
#   inflating: StratosphereLinuxIPS-master/modules/rnn-cc-detection/rnn_model.h5
#    creating: StratosphereLinuxIPS-master/modules/rnn-cc-detection/training_code/
#   inflating: StratosphereLinuxIPS-master/modules/rnn-cc-detection/training_code/rnn_model_training.py
#    creating: StratosphereLinuxIPS-master/modules/template/
#   inflating: StratosphereLinuxIPS-master/modules/template/__init__.py
#   inflating: StratosphereLinuxIPS-master/modules/template/template.py
#    creating: StratosphereLinuxIPS-master/modules/threat_intelligence/
#   inflating: StratosphereLinuxIPS-master/modules/threat_intelligence/__init__.py
#   inflating: StratosphereLinuxIPS-master/modules/threat_intelligence/threat_intelligence.py
#   inflating: StratosphereLinuxIPS-master/modules/threat_intelligence/urlhaus.py
#    creating: StratosphereLinuxIPS-master/modules/timeline/
#   inflating: StratosphereLinuxIPS-master/modules/timeline/__init__.py
#   inflating: StratosphereLinuxIPS-master/modules/timeline/timeline.py
#    creating: StratosphereLinuxIPS-master/modules/update_manager/
#   inflating: StratosphereLinuxIPS-master/modules/update_manager/__init__.py
#   inflating: StratosphereLinuxIPS-master/modules/update_manager/timer_manager.py
#   inflating: StratosphereLinuxIPS-master/modules/update_manager/update_file_manager.py
#   inflating: StratosphereLinuxIPS-master/modules/update_manager/update_manager.py
#    creating: StratosphereLinuxIPS-master/modules/virustotal/
#  extracting: StratosphereLinuxIPS-master/modules/virustotal/__init__.py
#    creating: StratosphereLinuxIPS-master/modules/virustotal/data/
#    creating: StratosphereLinuxIPS-master/modules/virustotal/data/demo/
#   inflating: StratosphereLinuxIPS-master/modules/virustotal/data/demo/README
#   inflating: StratosphereLinuxIPS-master/modules/virustotal/data/demo/benign_in
#   inflating: StratosphereLinuxIPS-master/modules/virustotal/data/demo/benign_out_bkp
#   inflating: StratosphereLinuxIPS-master/modules/virustotal/data/demo/malicious_in
#   inflating: StratosphereLinuxIPS-master/modules/virustotal/data/demo/malicious_out_bkp
#   inflating: StratosphereLinuxIPS-master/modules/virustotal/data/vt_ip_ratios.png
#   inflating: StratosphereLinuxIPS-master/modules/virustotal/virustotal.py
#    creating: StratosphereLinuxIPS-master/p2p4slips/
#   inflating: StratosphereLinuxIPS-master/requirements.txt
#   inflating: StratosphereLinuxIPS-master/slips.py
#    creating: StratosphereLinuxIPS-master/slips_files/
#   inflating: StratosphereLinuxIPS-master/slips_files/__init__.py
#    creating: StratosphereLinuxIPS-master/slips_files/common/
#  extracting: StratosphereLinuxIPS-master/slips_files/common/__init__.py
#   inflating: StratosphereLinuxIPS-master/slips_files/common/abstracts.py
#   inflating: StratosphereLinuxIPS-master/slips_files/common/argparse.py
#   inflating: StratosphereLinuxIPS-master/slips_files/common/config_parser.py
#   inflating: StratosphereLinuxIPS-master/slips_files/common/markov_chains.py
#   inflating: StratosphereLinuxIPS-master/slips_files/common/slips_utils.py
#    creating: StratosphereLinuxIPS-master/slips_files/core/
#  extracting: StratosphereLinuxIPS-master/slips_files/core/__init__.py
#    creating: StratosphereLinuxIPS-master/slips_files/core/database/
#  extracting: StratosphereLinuxIPS-master/slips_files/core/database/__init__.py
#   inflating: StratosphereLinuxIPS-master/slips_files/core/database/_profile_flow.py
#   inflating: StratosphereLinuxIPS-master/slips_files/core/database/database.py
#   inflating: StratosphereLinuxIPS-master/slips_files/core/evidenceProcess.py
#   inflating: StratosphereLinuxIPS-master/slips_files/core/filemonitor.py
#   inflating: StratosphereLinuxIPS-master/slips_files/core/guiProcess.py
#   inflating: StratosphereLinuxIPS-master/slips_files/core/inputProcess.py
#   inflating: StratosphereLinuxIPS-master/slips_files/core/logsProcess.py
#   inflating: StratosphereLinuxIPS-master/slips_files/core/notify.py
#   inflating: StratosphereLinuxIPS-master/slips_files/core/outputProcess.py
#   inflating: StratosphereLinuxIPS-master/slips_files/core/profilerProcess.py
#   inflating: StratosphereLinuxIPS-master/slips_files/core/whitelist.py
#    creating: StratosphereLinuxIPS-master/slips_files/organizations_info/
#   inflating: StratosphereLinuxIPS-master/slips_files/organizations_info/apple
#   inflating: StratosphereLinuxIPS-master/slips_files/organizations_info/apple_asn
#   inflating: StratosphereLinuxIPS-master/slips_files/organizations_info/apple_domains
#   inflating: StratosphereLinuxIPS-master/slips_files/organizations_info/facebook
#   inflating: StratosphereLinuxIPS-master/slips_files/organizations_info/facebook_asn
#   inflating: StratosphereLinuxIPS-master/slips_files/organizations_info/facebook_domains
#   inflating: StratosphereLinuxIPS-master/slips_files/organizations_info/google
#   inflating: StratosphereLinuxIPS-master/slips_files/organizations_info/google_asn
#   inflating: StratosphereLinuxIPS-master/slips_files/organizations_info/google_domains
#   inflating: StratosphereLinuxIPS-master/slips_files/organizations_info/microsoft
#   inflating: StratosphereLinuxIPS-master/slips_files/organizations_info/microsoft_asn
#   inflating: StratosphereLinuxIPS-master/slips_files/organizations_info/microsoft_domains
#   inflating: StratosphereLinuxIPS-master/slips_files/organizations_info/twitter
#   inflating: StratosphereLinuxIPS-master/slips_files/organizations_info/twitter_asn
#   inflating: StratosphereLinuxIPS-master/slips_files/organizations_info/twitter_domains
#    creating: StratosphereLinuxIPS-master/slips_files/ports_info/
#   inflating: StratosphereLinuxIPS-master/slips_files/ports_info/ports_used_by_specific_orgs.csv
#   inflating: StratosphereLinuxIPS-master/slips_files/ports_info/services.csv
#    creating: StratosphereLinuxIPS-master/tests/
#  extracting: StratosphereLinuxIPS-master/tests/__init__.py
#   inflating: StratosphereLinuxIPS-master/tests/destrctor.py
#    creating: StratosphereLinuxIPS-master/tests/integration_tests/
#  extracting: StratosphereLinuxIPS-master/tests/integration_tests/__init__.py
#   inflating: StratosphereLinuxIPS-master/tests/integration_tests/test.conf
#   inflating: StratosphereLinuxIPS-master/tests/integration_tests/test2.conf
#   inflating: StratosphereLinuxIPS-master/tests/integration_tests/test_config_files.py
#   inflating: StratosphereLinuxIPS-master/tests/integration_tests/test_dataset.py
#   inflating: StratosphereLinuxIPS-master/tests/run_all_tests.sh
#   inflating: StratosphereLinuxIPS-master/tests/test_arp.py
#   inflating: StratosphereLinuxIPS-master/tests/test_blocking.py
#   inflating: StratosphereLinuxIPS-master/tests/test_daemon.py
#   inflating: StratosphereLinuxIPS-master/tests/test_database.py
#   inflating: StratosphereLinuxIPS-master/tests/test_flowalerts.py
#   inflating: StratosphereLinuxIPS-master/tests/test_http_analyzer.py
#   inflating: StratosphereLinuxIPS-master/tests/test_inputProc.py
#   inflating: StratosphereLinuxIPS-master/tests/test_ip_info.py
#   inflating: StratosphereLinuxIPS-master/tests/test_leak_detector.py
#   inflating: StratosphereLinuxIPS-master/tests/test_profilerProcess.py
#   inflating: StratosphereLinuxIPS-master/tests/test_slips.py
#   inflating: StratosphereLinuxIPS-master/tests/test_slips_utils.py
#   inflating: StratosphereLinuxIPS-master/tests/test_threat_intelligence.py
#   inflating: StratosphereLinuxIPS-master/tests/test_update_file_manager.py
#   inflating: StratosphereLinuxIPS-master/tests/test_virustotal.py
#   inflating: StratosphereLinuxIPS-master/tests/test_whitelist.conf
#   inflating: StratosphereLinuxIPS-master/tests/test_whitelist.py
#    creating: StratosphereLinuxIPS-master/tests/yara_rules_for_testing/
#    creating: StratosphereLinuxIPS-master/tests/yara_rules_for_testing/rules/
#   inflating: StratosphereLinuxIPS-master/tests/yara_rules_for_testing/rules/test_rule.yara
#   inflating: StratosphereLinuxIPS-master/webinterface.sh
#    creating: StratosphereLinuxIPS-master/webinterface/
#    creating: StratosphereLinuxIPS-master/webinterface/analysis/
#  extracting: StratosphereLinuxIPS-master/webinterface/analysis/__init__.py
#   inflating: StratosphereLinuxIPS-master/webinterface/analysis/analysis.py
#    creating: StratosphereLinuxIPS-master/webinterface/analysis/static/
#    creating: StratosphereLinuxIPS-master/webinterface/analysis/static/css/
#   inflating: StratosphereLinuxIPS-master/webinterface/analysis/static/css/style.css
#    creating: StratosphereLinuxIPS-master/webinterface/analysis/static/js/
#   inflating: StratosphereLinuxIPS-master/webinterface/analysis/static/js/analysis.js
#   inflating: StratosphereLinuxIPS-master/webinterface/analysis/static/js/tableDefs.js
#    creating: StratosphereLinuxIPS-master/webinterface/analysis/templates/
#   inflating: StratosphereLinuxIPS-master/webinterface/analysis/templates/analysis.html
#   inflating: StratosphereLinuxIPS-master/webinterface/app.py
#    creating: StratosphereLinuxIPS-master/webinterface/database/
#  extracting: StratosphereLinuxIPS-master/webinterface/database/__init__.py
#   inflating: StratosphereLinuxIPS-master/webinterface/database/database.py
#   inflating: StratosphereLinuxIPS-master/webinterface/database/signals.py
#    creating: StratosphereLinuxIPS-master/webinterface/general/
#  extracting: StratosphereLinuxIPS-master/webinterface/general/__init__.py
#   inflating: StratosphereLinuxIPS-master/webinterface/general/general.py
#    creating: StratosphereLinuxIPS-master/webinterface/general/static/
#    creating: StratosphereLinuxIPS-master/webinterface/general/static/css/
#  extracting: StratosphereLinuxIPS-master/webinterface/general/static/css/style.css
#    creating: StratosphereLinuxIPS-master/webinterface/general/static/js/
#   inflating: StratosphereLinuxIPS-master/webinterface/general/static/js/general.js
#    creating: StratosphereLinuxIPS-master/webinterface/general/templates/
#   inflating: StratosphereLinuxIPS-master/webinterface/general/templates/general.html
#    creating: StratosphereLinuxIPS-master/webinterface/static/
#   inflating: StratosphereLinuxIPS-master/webinterface/static/app.js
#    creating: StratosphereLinuxIPS-master/webinterface/templates/
#   inflating: StratosphereLinuxIPS-master/webinterface/templates/app.html
#    creating: StratosphereLinuxIPS-master/webinterface/tests/
#   inflating: StratosphereLinuxIPS-master/webinterface/tests/redis_tests.py
#   inflating: StratosphereLinuxIPS-master/webinterface/utils.py
#    creating: StratosphereLinuxIPS-master/zeek-scripts/
#   inflating: StratosphereLinuxIPS-master/zeek-scripts/__load__.zeek
#   inflating: StratosphereLinuxIPS-master/zeek-scripts/arp.zeek
#   inflating: StratosphereLinuxIPS-master/zeek-scripts/detect_DoH.zeek
#   inflating: StratosphereLinuxIPS-master/zeek-scripts/hash_sha256.zeek
#   inflating: StratosphereLinuxIPS-master/zeek-scripts/icmp-scans.zeek
#   inflating: StratosphereLinuxIPS-master/zeek-scripts/ja3.zeek
#   inflating: StratosphereLinuxIPS-master/zeek-scripts/ja3s.zeek
#   inflating: StratosphereLinuxIPS-master/zeek-scripts/log_gw.zeek
#   inflating: StratosphereLinuxIPS-master/zeek-scripts/slips-conf.zeek

# %%
# !ls -R ./docs
# Out:
# ./docs:
# architecture.md        FAQ.md		Makefile
# code_documentation.md  features.md	P2P.md
# conf.py		       flowalerts.md	slips_in_action.md
# contributing.md        images		training.md
# create_new_module.md   index.rst	usage.md
# detection_modules.md   installation.md
# exporting.md	       make.bat
#
# ./docs/images:
# alerts_log.png			   qakbot.png
# directions.png			   saefko_first_alert.png
# droidjack_alert.png		   slips.gif
# emotet_alerts.png		   slips_internal_architecture.jpg
# expanding_infected_timewindow.png  slips_logo.png
# kalipso.png			   slips_workflow.png
# kalispo_infected_tw.png		   trickbot.png
# module.gif			   updating_remote_feeds.png
# modules_starting.png		   web_interface.png

# %%
import os

# Load the files in the current directory
dir_files = []
docs_contents = os.listdir('docs')

# Loop through each file and print its name if it's a file
for item in docs_contents:
    item_path = os.path.join('docs', item)
    if os.path.isfile(item_path):
        dir_files.append(item_path)

# Load the contents of all the files and concatenate them into a single string
all_text = ""
for file_name in dir_files:
    with open(file_name, 'r') as file:
        content = file.read()
        all_text += content + "\n"

# %%
len(all_text)
# Out:
# 184644

# %%
print(all_text)

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from string import punctuation

nltk.download('punkt')
nltk.download('stopwords')

# Tokenize the text into words
words = word_tokenize(all_text)

# Remove stop words and punctuation marks
stop_words = set(stopwords.words('english'))
cleaned_words = [word for word in words if word.lower() not in stop_words and word not in punctuation]

# Join the cleaned words into a string
cleaned_text = ' '.join(cleaned_words)

print(cleaned_text)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Contributing contributions welcomed thank taking time contribute project set guidelines contributing development Slips 1 contribute Run Slips report bugs needed features suggest ideas Pull requests solved GitHub issue new feature Pull request new detection module Persistent Git Branches following git branches Slips repository permanent master contains stable version Slips new versions least month develop contains latest unstable version Slips also latest features new features based branch Naming Git branches Pull Requests keep Git history clean facilitate revision contributions ask branches follow concise namings branch-naming patterns follow contributing Slips author-bugfix- pull request branch contains one bugfix author-docs- pull request branch contains documentation work author-enhance- pull request branch contains one enhancement new feature improvement nonetheless author-feature- pull request branch contains new feature author-refactor- pull request branch contains code refactoring branch base contribution Slips general rule base contributions develop branch Creating pull request Commits Commits follow KISS principle one thing well keep simple stupid Commit messages easily readable imperative style `` Fix memory leak ... '' `` FixES mem ... '' Pull Requests developed multiple features and/or bugfixes create separate branches one request merges branch PR develop trigger develop Github checks checks run Slips unit tests integration tests locally ubuntu VM docker make sure branch ready merge PRs wo n't merged unless checks pass cleaner code/change/changeset faster merged Beginner tips create PR Slips 's simple beginner-level steps create PR Slips 1 Clone Slips repo 2 clone checkout origin/develop `` git checkout origin develop `` 3 Create branch develop using name feature name `` git checkout -b yourname feature_name develop `` 4 Change code add feature fix bug etc commit descriptive msg `` git commit -m `` descriptive msg '' `` 5 Test code important step n't open PR code working `` ./tests/run_all_tests.sh `` 6 tests n't pass means need fix something branch 7 Push repo `` git push -u origin yourname feature_name `` 8 Open PR Slips remember set base branch develop 9 List changes PR description IDEs like PyCharm https //www.jetbrains.com/help/pycharm/work-with-github-pull-requests.html vscode https //levelup.gitconnected.com/how-to-create-a-pull-request-on-github-using-vs-code-f03db28308c4 option open PR within IDE 's ready-to-merge PR 1 contributions guidelines inspired project Snoopy https //raw.githubusercontent.com/a2o/snoopy/master/.github/CONTRIBUTING.md ﻿ Slips Action demonstrate capabilities Slips give real life malware traffic checking Slips analyses img src= '' https //raw.githubusercontent.com/stratosphereips/StratosphereLinuxIPS/develop/docs/images/slips.gif '' title= '' Slips action `` Saefko RAT provide analysis network traffic RAT06-Saefko download https //mcfp.felk.cvut.cz/publicDatasets/Android-Mischief-Dataset/AndroidMischiefDataset_v2/RAT06_Saefko/ using Slips capture contains different actions done RAT controller e.g upload file get GPS location monitor files etc. detailed analysis check Kamila Babayeva 's blog Dissecting RAT Analysis Saefko RAT https //www.stratosphereips.org/blog/2021/6/2/dissecting-a-rat-analysis-of-the-saefko-rat analysis know controller IP address 192.168.131.1 2001:718:2:903 f410:3340 d02b b918 victim 's IP address 192.168.131.2 2001:718:2:903 b877:48ae:9531 fbfc First run slips using following command ./slips.py -e 1 -f RAT06_Saefko.pcap First Slips start updating remote TI feeds added slips.conf img src= '' https //raw.githubusercontent.com/stratosphereips/StratosphereLinuxIPS/develop/docs/images/updating_remote_feeds.png '' title= '' Slips updating remote TI feeds '' make sure Slips date recent IoCs feeds feeds loaded parsed updated periodically automatically Slips every 24 hours Update Manager https //stratospherelinuxips.readthedocs.io/en/develop/detection_modules.html update-m ...

# %%
len(cleaned_text)
# Out:
# 137097

# %%
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

stop_words = set(stopwords.words('english'))

tokens = nltk.word_tokenize(cleaned_text)
pos_tags = nltk.pos_tag(tokens)

filtered_tokens = [word for word, tag in pos_tags if not word.lower() in stop_words and not tag.startswith('P') and not tag.startswith('C')]

cleaned_text = ' '.join(filtered_tokens)
print(cleaned_text)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# Contributing contributions welcomed thank taking time contribute project set guidelines contributing development Slips contribute Run Slips report bugs needed features suggest ideas Pull requests solved GitHub issue new feature Pull request new detection module Persistent Git Branches following git branches Slips repository permanent master contains stable version Slips new versions least month develop contains latest unstable version Slips also latest features new features based branch Naming Git branches Pull Requests keep Git history clean facilitate revision contributions ask branches follow concise namings branch-naming patterns follow contributing Slips author-bugfix- pull request branch contains bugfix author-docs- pull request branch contains documentation work author-enhance- pull request branch contains enhancement new feature improvement nonetheless author-feature- pull request branch contains new feature author-refactor- pull request branch contains code refactoring branch base contribution Slips general rule base contributions develop branch Creating pull request Commits Commits follow KISS principle thing well keep simple stupid Commit messages easily readable imperative style `` Fix memory leak ... `` `` FixES mem ... `` Pull Requests developed multiple features and/or bugfixes create separate branches request merges branch PR develop trigger develop Github checks checks run Slips unit tests integration tests locally ubuntu VM docker make sure branch ready merge PRs wo n't merged unless checks pass cleaner code/change/changeset faster merged Beginner tips create PR Slips simple beginner-level steps create PR Slips Clone Slips repo clone checkout origin/develop `` git checkout origin develop `` Create branch develop using name feature name `` git checkout -b yourname feature_name develop `` Change code add feature fix bug etc commit descriptive msg `` git commit -m `` descriptive msg `` `` Test code important step n't open PR code working `` ./tests/run_all_tests.sh `` tests n't pass means need fix something branch Push repo `` git push -u origin yourname feature_name `` Open PR Slips remember set base branch develop List changes PR description IDEs like PyCharm https //www.jetbrains.com/help/pycharm/work-with-github-pull-requests.html vscode https //levelup.gitconnected.com/how-to-create-a-pull-request-on-github-using-vs-code-f03db28308c4 option open PR within IDE ready-to-merge PR contributions guidelines inspired project Snoopy https //raw.githubusercontent.com/a2o/snoopy/master/.github/CONTRIBUTING.md ﻿ Slips Action demonstrate capabilities Slips give real life malware traffic checking Slips analyses img src= `` https //raw.githubusercontent.com/stratosphereips/StratosphereLinuxIPS/develop/docs/images/slips.gif `` title= `` Slips action `` Saefko RAT provide analysis network traffic RAT06-Saefko download https //mcfp.felk.cvut.cz/publicDatasets/Android-Mischief-Dataset/AndroidMischiefDataset_v2/RAT06_Saefko/ using Slips capture contains different actions done RAT controller e.g upload file get GPS location monitor files etc . detailed analysis check Kamila Babayeva blog Dissecting RAT Analysis Saefko RAT https //www.stratosphereips.org/blog/2021/6/2/dissecting-a-rat-analysis-of-the-saefko-rat analysis know controller IP address f410:3340 d02b b918 victim IP address b877:48ae:9531 fbfc First run slips using following command ./slips.py -e -f RAT06_Saefko.pcap First Slips start updating remote TI feeds added slips.conf img src= `` https //raw.githubusercontent.com/stratosphereips/StratosphereLinuxIPS/develop/docs/images/updating_remote_feeds.png `` title= `` Slips updating remote TI feeds `` make sure Slips date recent IoCs feeds feeds loaded parsed updated periodically automatically Slips every hours Update Manager https //stratospherelinuxips.readthedocs.io/en/develop/detection_modules.html update-manager-module requires user interaction Afetr updating slips modules start print PID every successfully started  ...

# %%
cleaned_text = cleaned_text.replace("#", "")

# %%
len(cleaned_text)
# Out:
# 131837

# %%
all_text=cleaned_text

# %%
len(all_text)
# Out:
# 131837

# %%
import re
sentences =re.split(r'[.\n]',all_text)
print(len(sentences))
# Out:
# 1052

# %%
sentences
# Out:
# ['Contributing contributions welcomed thank taking time contribute project set guidelines contributing development Slips contribute Run Slips report bugs needed features suggest ideas Pull requests solved GitHub issue new feature Pull request new detection module Persistent Git Branches following git branches Slips repository permanent master contains stable version Slips new versions least month develop contains latest unstable version Slips also latest features new features based branch Naming Git branches Pull Requests keep Git history clean facilitate revision contributions ask branches follow concise namings branch-naming patterns follow contributing Slips author-bugfix- pull request branch contains bugfix author-docs- pull request branch contains documentation work author-enhance- pull request branch contains enhancement new feature improvement nonetheless author-feature- pull request branch contains new feature author-refactor- pull request branch contains code refactoring branch base contribution Slips general rule base contributions develop branch Creating pull request Commits Commits follow KISS principle thing well keep simple stupid Commit messages easily readable imperative style `` Fix memory leak ',
#  '',
#  '',
#  ' `` `` FixES mem ',
#  '',
#  '',
#  " `` Pull Requests developed multiple features and/or bugfixes create separate branches request merges branch PR develop trigger develop Github checks checks run Slips unit tests integration tests locally ubuntu VM docker make sure branch ready merge PRs wo n't merged unless checks pass cleaner code/change/changeset faster merged Beginner tips create PR Slips simple beginner-level steps create PR Slips Clone Slips repo clone checkout origin/develop `` git checkout origin develop `` Create branch develop using name feature name `` git checkout -b yourname feature_name develop `` Change code add feature fix bug etc commit descriptive msg `` git commit -m `` descriptive msg `` `` Test code important step n't open PR code working `` ",
#  '/tests/run_all_tests',
#  "sh `` tests n't pass means need fix something branch Push repo `` git push -u origin yourname feature_name `` Open PR Slips remember set base branch develop List changes PR description IDEs like PyCharm https //www",
#  'jetbrains',
#  'com/help/pycharm/work-with-github-pull-requests',
#  'html vscode https //levelup',
#  'gitconnected',
#  'com/how-to-create-a-pull-request-on-github-using-vs-code-f03db28308c4 option open PR within IDE ready-to-merge PR contributions guidelines inspired project Snoopy https //raw',
#  'githubusercontent',
#  'com/a2o/snoopy/master/',
#  'github/CONTRIBUTING',
#  'md \ufeff Slips Action demonstrate capabilities Slips give real life malware traffic checking Slips analyses img src= `` https //raw',
#  'githubusercontent',
#  'com/stratosphereips/StratosphereLinuxIPS/develop/docs/images/slips',
#  'gif `` title= `` Slips action `` Saefko RAT provide analysis network traffic RAT06-Saefko download https //mcfp',
#  'felk',
#  'cvut',
#  'cz/publicDatasets/Android-Mischief-Dataset/AndroidMischiefDataset_v2/RAT06_Saefko/ using Slips capture contains different actions done RAT controller e',
#  'g upload file get GPS location monitor files etc ',
#  ' detailed analysis check Kamila Babayeva blog Dissecting RAT Analysis Saefko RAT https //www',
#  'stratosphereips',
#  'org/blog/2021/6/2/dissecting-a-rat-analysis-of-the-saefko-rat analysis know controller IP address f410:3340 d02b b918 victim IP address b877:48ae:9531 fbfc First run slips using following command ',
#  '/slips',
#  'py -e -f RAT06_Saefko',
#  'pcap First Slips start updating remote TI feeds added slips',
#  'conf img src= `` https //raw',
#  'githubusercontent',
#  'com/stratosphereips/StratosphereLinuxIPS/develop/docs/images/updating_remote_feeds',
#  'png `` title= `` Slips updating remote TI feeds `` make sure Slips date recent IoCs feeds feeds loaded parsed updated periodically automatically Slips every hours Update Manager https //stratospherelinuxips',
#  'readthedocs',
#  'io/en/develop/detection_modules',
#  'html update-manager-module requires user interaction Afetr updating slips modules start print PID every successfully started module img src= `` https //raw',
#  'githubusercontent',
#  'com/stratosphereips/StratosphereLinuxIPS/develop/docs/images/modules_starting',
#  'png `` title= `` Slips modules starting `` see get alert saefko_first_alert',
#  'png Alerts printed evidence module Slips detected IP b877:48ae:9531 fbfc infected due evidence See difference alerts evidence https //stratospherelinuxips',
#  'readthedocs',
#  'io/en/develop/architecture',
#  'html Slips splits detections timewindows time window hour long default contains dozens features computed connections start time window IP behaves maliciously PM marked infected hour next hour malicious behaviour occurs slips treat traffic normal explains start stop timestamps alert start 2021-04-10T16:44:43',
#  '285478+02:00 stop 2021-04-10T17:44:43',
#  '285478+0200 period timewindow IP behaving maliciously difference infected normal timewindows shown better kalispo https //stratospherelinuxips',
#  'readthedocs',
#  'io/en/develop/usage',
#  'html reading-the-output user interface start another terminal using ',
#  '/kalipso',
#  'sh img src= `` https //raw',
#  'githubusercontent',
#  'com/stratosphereips/StratosphereLinuxIPS/develop/docs/images/kalispo_infected_tw',
#  'png `` title= `` Kalipso infected timewindow `` p Figure /p see IP b877:48ae:9531 fbfc infected timewindow1 marked red behaving normally timewindow0 colored green see flows done IP infected timewindow kalipso pressing enter timewindow1 img src= `` https //raw',
#  'githubusercontent',
#  'com/stratosphereips/StratosphereLinuxIPS/develop/docs/images/expanding_infected_timewindow',
#  'png `` title= `` Kalipso expanding infected timewindow `` bottom box kalipso scroll though evidence se slips detected evidence printed Figure see following detections evidence Detected Malicious JA3 source address b877:48ae:9531 fbfc CESNET z',
#  's',
#  'p',
#  "o description Tofsee 'malicious JA3 fingerprint client part SSL certificate indicates source IP b877:48ae:9531 fbfc infected Tofsee malware family Slips also detected connection database SSL certificate validation failed certificate expired Destination IP dead d8f :1 SNI experimentsas",
#  '000webhostapp',
#  'com RAT analysis know web hosting service used C C server Slips also detected Connection unknown destination port destination IP a191 : fff:1 Connection unknown destination port destination IP APK list IRC servers shown RAT analysis know phone connects port different IRC servers receive malicious commands rDNS server also printed alert open',
#  'ircnet',
#  "net machine learning module rnn-cc-detection detected C C server using recurrent neural network Detected C C channel destination IP port score Slips also detected Possible DGA domain scanning failed resolve domains detections evidence accumulated resulted alert view evidence slips detected including n't enough generate alert cat output/alerts",
#  'log img src= `` https //raw',
#  'githubusercontent',
#  'com/stratosphereips/StratosphereLinuxIPS/develop/docs/images/alerts_log',
#  'png `` title= `` Slips updating remote TI feeds `` Slips also another log file JSON format easily parsed exported See exporting section https //stratospherelinuxips',
#  'readthedocs',
#  'io/en/develop/exporting',
#  'html documentation generated alerts file follow CESNET IDEA0 format https //idea',
#  'cesnet',
#  'cz/en/index cat output/alerts',
#  'json -- Emotet analysing several Emotet PCAPs starting infection Trickbot Qakbot malwares dropped captures contain different actions done Emotet trickbot controller detailed analysis check Paloalto blog Examining Emotet Infection Traffic https //unit42',
#  'paloaltonetworks',
#  'com/wireshark-tutorial-emotet-infection/ text=Example Emotet infection analysing Emotet PCAP download https //github',
#  'com/pan-unit42/wireshark-tutorial-Emotet-traffic/blob/main/Example-1-2021-01-06-Emotet-infection',
#  'pcap',
#  'zip password infected running Slips PCAP ',
#  '/slips',
#  'py -f Example-1-2021-01-06-Emotet-infection',
#  'pcap get following alerts img src= `` https //raw',
#  'githubusercontent',
#  'com/stratosphereips/StratosphereLinuxIPS/develop/docs/images/emotet_alerts',
#  'png `` title= `` Slips generated Emotet alerts `` reconnection attemps shown analysis img src= `` https //unit42',
#  'paloaltonetworks',
#  'com/wp-content/uploads/2021/01/word-image-45',
#  'jpeg `` title= `` Slips generated Emotet alerts `` detected Slips following evidence Detected connection without DNS resolution IP Detected Multiple reconnection attempts Destination IP IP Trickbot Analyzing next PCAP download https //github',
#  'com/pan-unit42/wireshark-tutorial-Emotet-traffic/blob/main/Example-4-2021-01-05-Emotet-infection-with-Trickbot',
#  'pcap',
#  'zip contains Trickbot traffic password infected Running slips pcap ',
#  '/slips',
#  'py -f Example-4-2021-01-05-Emotet-infection-with-Trickbot',
#  'pcap img src= `` https //raw',
#  'githubusercontent',
#  'com/stratosphereips/StratosphereLinuxIPS/develop/docs/images/trickbot',
#  'png `` title= `` Slips generated Trickbot alerts `` Slips detects signed SSL certificate trickbot IP associated data exfiltration Detected SSL certificate validation failed self signed certificate Destination IP Slips also detected Detected connection without DNS resolution IP ',
#  ' Detected Connection unknown destination port destination IP Qakbot Analyzing next PCAP download https //github',
#  'com/pan-unit42/wireshark-tutorial-Emotet-traffic/blob/main/Example-5-2020-08-18-Emotet-infection-with-Qakbot',
#  'pcap',
#  'zip contains Qakbot traffic password infected Running slips pcap ',
#  '/slips',
#  'py -f Example-5-2020-08-18-Emotet-infection-with-Qakbot',
#  'pcap img src= `` https //raw',
#  'githubusercontent',
#  'com/stratosphereips/StratosphereLinuxIPS/develop/docs/images/qakbot',
#  "png `` title= `` Slips generated Trickbot alerts `` Slips detected victim infected Qakbo using JA3 Detected Malicious JA3 source address description Quakbot 'malicious Detected Malicious JA3 source address description Gozi 'malicious also see Domain generation algorithm detection victim Detected possible DGA domain scanning failed resolve domains expired certificate samaritantec",
#  'com domain reported hosting Emotet binary date https //urlhaus',
#  'abuse',
#  'ch/url/436011/ Detected SSL certificate validation failed certificate expired Destination IP SNI samaritantec',
#  'com Slips detected Detected C C channel destination IP port score etected connection without DNS resolution IP CHARTER-20115 rDNS 071-080-066-107',
#  'res',
#  'spectrum',
#  'com quick search virustotal shows IP associated qakbot https //www',
#  'vmray',
#  'com/cyber-security-blog/qbot-delivery-method-malware-analysis/ port scan Detected horizontal port scan port unique dst IPs Tot pkts Threat Level medium -- DroidJack v4',
#  '4 RAT Running Slips DroidJack v4',
#  '4 RAT download https //mcfp',
#  'felk',
#  'cvut',
#  'cz/publicDatasets/Android-Mischief-Dataset/AndroidMischiefDataset_v1/DroidJack',
#  'zip password infected capture contains different actions done RAT controller e',
#  'g upload file get GPS location monitor files etc ',
#  ' detailed analysis check Kamila Babayeva blog Analysis DroidJack v4',
#  '4 RAT network traffic https //www',
#  'stratosphereips',
#  'org/blog/2021/1/22/analysis-of-droidjack-v44-rat-network-traffic analysis know controller IP address victim IP address running slips PCAP ',
#  '/slips',
#  'py -f RAT02',
#  'pcap get following alerts img src= `` https //raw',
#  'githubusercontent',
#  'com/stratosphereips/StratosphereLinuxIPS/develop/docs/images/droidjack_alert',
#  'png `` title= `` Slips generated DroidJack alerts `` Slips detected connection C C server using unknown port Detected Connection unknown destination port destination IP Slips also detected reconnection attemps made victim C C server Multiple reconnection attempts Destination IP IP Slips also detects connections without resolutions due wide usages among malware check internet connectivity get commands fro C C servers Detected connection without DNS resolution IP CESNET z',
#  's',
#  'p',
#  'o ',
#  ' rDNS dhcp-83-253',
#  'felk',
#  'cvut',
#  'cz indentification SNI rDNS IP available printed every evidence generated Slips Threat intelligence feed Abuse',
#  'ch https //sslbl',
#  'abuse',
#  'ch/blacklist/ja3_fingerprints',
#  "csv detected malicious JA3 indicating victim infected Detected Malicious JA3 source address description 'malicious machine learning models detected C C server Detected C C channel destination IP port score Slips creates profile per IP appeared traffic profile contains flows sent IP flow described specific letter description found https //www",
#  'stratosphereips',
#  'org/stratosphere-testing-framework Considering Slips detects C C channel Slips ’ machine learning module called LSTM detecting C C channel shown img src= `` https //images',
#  'squarespace-cdn',
#  'com/content/v1/5a01100f692ebe0459a1859f/1611308467564-L34N8ANZOO8WUIO9OT7O/image2',
#  'png `` title= `` Behavioral model connection phone C C `` Slips detect periodic connection LSTM module focuses TCP behavioral model connections shown conclude model periodic connections small size img src= `` https //images',
#  'squarespace-cdn',
#  'com/content/v1/5a01100f692ebe0459a1859f/1611308530585-BKXFXAQXGFIPXPRLSSVF/image5',
#  'png `` title= `` Behavioral model created Slips connection phone server using `` Exporting Slips supports exporting alerts systems using different modules ExportingAlerts CESNET sharing etc supported systems Slack TAXII Servers STIX format Warden servers IDEA JSON format Logstash Slack Slips uses WebHook method send data Slack info https //api',
#  'slack',
#  'com/messaging/webhooks export slack channel need Create new application slack see https //api',
#  'slack',
#  'com/apps/ Remember applications seen per user users Slack see application probably Activate Incoming Webhooks creating app Create Incoming Webhook channel want send messages Go Slack copy channel ID channel going channel clicking channel name ID bottom pop-up window need give app correct scope Slips needs write access channel Go app Slack https //api',
#  'slack',
#  "com/apps navigation menu choose OAuth Permissions feature Scroll Scopes section pick channels read chat write drop menu Scroll back top page look button says Install App Workspace Reinstall App 've done Click 'OAuth Permissions page copy User OAuth Token look something like 'xoxb-nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn lot letters Put bot OAuth token file `` config/slack_bot_token_secret `` need add new app channel Slack clicking bot name messae add integration channel click app channel Alternatively add bot channel going channel `` /invite bots_name `` Edit config/slips",
#  'conf file put slack export\\_to variable add channel name want send exporting_alerts export_to slack slack_channel_name SlipsAlertsChannel STIX want export alerts TAXII server using STIX format change `` export_to `` variable export STIX Slips automatically generate `` STIX_data',
#  'json `` containing alerts detects ExportingAlerts export_to stix add TAXII server details following variables `` TAXII_server `` link TAXII server `` port `` port used `` use_https `` use https `` discovery_path `` `` inbox_path `` contain URIs full urls example `` python discovery_path /services/discovery-a inbox_path /services/inbox-a `` `` collection_name `` collection server want push STIX data `` push_delay `` time wait pushing STIX data server seconds used slips running non-stop e',
#  'g -i `` taxii_username `` TAXII server user credentials `` taxii_password `` TAXII server user password `` jwt_auth_path `` auth path JWT based authentication used usually /management/auth use get token TAXII server remote server set `` port `` running file Slips export server analysis done running interface Slips export server every push_delay seconds default JSON format default Slips logs alerts `` output/alerts',
#  'json `` CESNET IDEA0 format https //idea',
#  'cesnet',
#  'cz/en/index also JSON format CESNET Sharing Slips supports exporting alerts warden servers well importing alerts enable exporting set `` receive_alerts `` `` yes `` config/slips',
#  'conf default configuration file path specified `` configuration_file `` variable `` config/slips',
#  'conf `` default path `` config/warden',
#  'conf `` format `` warden',
#  'conf `` following `` `` url `` `` https //example',
#  'com/warden3 `` `` certfile `` `` cert',
#  'pem `` `` keyfile `` `` key',
#  'pem `` `` cafile `` `` /etc/ssl/certs/DigiCert_Assured_ID_Root_CA',
#  'pem `` `` timeout `` `` errlog `` `` file `` `` output/warden_logs/warden',
#  'err `` `` level `` `` debug `` `` filelog `` `` file `` `` output/warden_logs/warden',
#  'log `` `` level `` `` warning `` `` name `` `` com',
#  'example',
#  'warden',
#  'test `` `` get key certificate need run `` warden_apply',
#  'sh `` registered client_name password Full instructions https //warden',
#  'cesnet',
#  'cz/en/index `` name `` key registered warden node name evidence causing alert exported warden server alert generated See difference alerts evidence https //stratospherelinuxips',
#  'readthedocs',
#  'io/en/develop/architecture',
#  'html Slips architecture section change often get alerts import warden server default Slips imports alerts every day change changing `` receive_delay `` value `` config/slips',
#  'conf `` Slips logs alerts `` output/alerts',
#  'json `` CESNET IDEA0 format https //idea',
#  'cesnet',
#  'cz/en/index default Make sure DigiCert_Assured_ID_Root_CA somewhere accessible slips run slips root want leave `` /etc/ssl/certs/ `` Refer Detection modules section docs https //stratospherelinuxips',
#  'readthedocs',
#  'io/en/develop/detection_modules',
#  'html cesnet-sharing-module detailed instructions CESNET importing Logstash Slips logstash',
#  'conf file exports alerts',
#  'json given output file change output preference example elastic search stdout etc Text logs default output Slips stored `` output/ `` directory files alert',
#  'json IDEA0 format alerts',
#  'log human readable text format Minimal makefile Sphinx documentation set variables command line also environment first SPHINXOPTS SPHINXBUILD sphinx-build SOURCEDIR BUILDDIR _build Put first `` make `` without argument like `` make help `` help SPHINXBUILD -M help `` SOURCEDIR `` `` BUILDDIR `` SPHINXOPTS ',
#  'PHONY help Makefile Catch-all target route unknown targets Sphinx using new `` make mode `` option meant shortcut SPHINXOPTS Makefile SPHINXBUILD -M `` SOURCEDIR `` `` BUILDDIR `` SPHINXOPTS ECHO pushd ~dp0 REM Command file Sphinx documentation `` SPHINXBUILD `` == `` `` set SPHINXBUILD=sphinx-build set SOURCEDIR= set BUILDDIR=_build `` `` == `` `` goto help SPHINXBUILD NUL NUL errorlevel echo echo',
#  "The 'sphinx-build command found Make sure Sphinx echo",
#  "installed set SPHINXBUILD environment variable point full path 'sphinx-build executable Alternatively echo",
#  'may add Sphinx directory PATH echo echo',
#  "If n't Sphinx installed grab echo",
#  'http //sphinx-doc',
#  "org/ exit /b SPHINXBUILD -M SOURCEDIR BUILDDIR SPHINXOPTS goto end help SPHINXBUILD -M help SOURCEDIR BUILDDIR SPHINXOPTS end popd FAQ Slips starting slow docker Make sure 're running many containers time share kernel resources even though 're isolated Getting `` Illegal instruction `` error running slips tensorflow version 're using n't compatible architecture get `` Illegal instruction `` error slips terminate fix disable modules use tensorflow adding `` rnn-cc-detection flowmldetection `` `` disable `` key `` config/slips",
#  "conf `` Docker time syncs host add local /etc/localtime volume Slips Docker container using `` docker run -it -- rm -- net=host -- cap-add=NET_ADMIN -v /etc/localtime /etc/localtime ro -- name slips stratosphereips/slips latest `` Training Slips machine learning module retrained users done puttin slips training mode re-train machine learning models traffic default Slips includes already trained model data sometimes necessary adapt circumstances Slips module called 'flowmldetection module analyzes flows one formatted similarly conn",
#  'log Zeek file module enabled default testing mode module uses default SGDClassifier linear support vector machine SVM decision use SVM done algorithms used online learning extend current model new data re-train machine learning algorithm need following 1- Edit config/slips',
#  "conf file put Slips train mode Search word __train__ section __ flowmldetection __ uncomment __mode train__ comment __mode test__ look like flowmldetection mode used tell flowmldetection module flows received training label provided Parameters section mode train mode used training models test unknown data trained least 'Normal data data order test work mode test 2- Establish general label traffic want re-train support label per file Search parameters section choose type traffic send Slips Set label flows read normal malware directly option setting labels filter label normal label malicious label unknown edits run Slips usual type input example Zeek folder ",
#  '/slips',
#  'py -c config/slips',
#  'conf -f ~/my-computer-normal/ pcap file ',
#  '/slips',
#  'py -c config/slips',
#  'conf -f ~/my-computer-normal2',
#  'pcap 3- also malicious traffic first change label malicious config/slips',
#  'conf Set label flows read normal malware directly option setting labels filter label normal label malicious label unknown ',
#  '/slips',
#  'py -c config/slips',
#  'conf -f ~/my-computer-normal2',
#  'pcap edits run Slips usual type input example another pcap ',
#  '/slips',
#  'py -c config/slips',
#  'conf -f ~/malware1',
#  'pcap also run slips interface train directly data ',
#  '/slips',
#  'py -c config/slips',
#  'conf -i eth0 4- Finally use model put back __test__ mode configuration config/slips',
#  "conf flowmldetection mode used tell flowmldetection module flows received training label provided Parameters section mode train mode used training models test unknown data trained least 'Normal data data order test work mode test 5- Use slips normally files interfaces ",
#  '/slips',
#  'py -c config/slips',
#  'conf -i eth0 Flow Alerts module flow alerts several behavioral techniques detect attacks analyzing content flow alone detection techniques Long connections Successful SSH connections Connections without DNS resolution DNS resolutions IPs never used Connections unknown ports Data exfiltration Malicious JA3 hashes Connections port Multiple reconnection attempts Alerts Zeek Self-signed certs invalid certs port-scans address scans password guessing DGA Connection multiple ports Malicious SSL certificates Pastebin downloads Young domains Bad SMTP logins SMTP login bruteforce DNS ARPA Scans SSH version changing Incompatible CN Weird HTTP methods Non-SSL connections port Non-HTTP connections port Connection private IPs Connection private IPs outside current local network High entropy DNS TXT answers Devices changing IPs details detection follows Long Connections Detect connections long except multicast connections defualt connection considered long exceeds seconds Minutes threshold changed `` slips',
#  "conf `` changing value `` long_connection_threshold `` Connections without DNS resolution detect connections done without previous DNS resolution idea connection without DNS resolution slightly suspicious Slips runs capturing packets directly network device opposed example PCAP file detection ignore connections happen first minute operation Slips times Slips started computer already running many DNS connections already done waiting minutes decreases amount False Positives detection ignore certain IP addresses connection without DNS ok exceptions Private IPs Localhost IPs Reserved IPs including super broadcast IPv6 local-link IPs Multicast IPs Broadcast IPs private Well known organizations DNS resolutions well known orgs might done using DoH case slips n't know DNS resolution resolved domain wo n't dns",
#  "log simply ignore alerts type connected well known organizations particular Facebook Apple Google Twitter Microsoft Slips uses lists organizations information IPs IP ranges domains ASNs stored `` slips_files/organizations_info `` used check whether IP/domain flow belong known org Slips n't detect 'connection without DNS running interface except done instance IP check DoH section https //stratospherelinuxips",
#  'readthedocs',
#  'io/en/develop/detection_modules',
#  'html detect-doh docs info slips detects DoH Successful SSH connections Slips detects successful SSH connections using ways Using Zeek Zeek logs successful SSH connection ssh',
#  'log default bytes sent SSH connection bytes DNS resolutions without connection detect DNS resolutions connection done resolution without usage slightly suspicious domains excepted reverse DNS resolutions using in-addr',
#  'arpa domain ',
#  'local domains wild card domain Subdomains cymru',
#  'com since used ipwhois library get ASN IP range Ignore WPAD domain Windows Ignore domains without TLD Chrome test domains Connection unknown ports Slips list known ports located `` slips_files/ports_info/ports_used_by_specific_orgs',
#  'csv `` also list ports belong specific organization `` slips_files/ports_info/ports_used_by_specific_orgs',
#  "csv `` example even though n't well known port Apple uses Apple Push Notification Service APNS port n't files considered unknown Slips Slips detect established connections unknown ports Rejected connections established detected reconnection attempts details check Multiple reconnections https //stratospherelinuxips",
#  'readthedocs',
#  'io/en/develop/flowalerts',
#  "html multiple-reconnection-attempts Data Upload Slips generates 'possible data upload alerts number uploaded bytes IP exceeds MBs timewindow period default See detailed explanation timewindows https //stratospherelinuxips",
#  'readthedocs',
#  'io/en/develop/architecture',
#  'html highlight=timewindows architecture number MBs modified changing value `` data_exfiltration_threshold `` `` slips',
#  'conf `` Slips also detects data upload IP uploads =100MBs IP connections Malicious JA3 JA3s hashes Slips uses JA3 hashes detect C C servers JA3s infected clients JA3 Slips shipped ’ zeek scripts add JA3 JA3s fingerprints SSL log files generated zeek Slips supports JA3 feeds addition different threat intelligence feeds JA3 feeds contain JA3 fingerprints identified malicious JA3 threat intelligence feed used Slips Abuse',
#  'ch JA3 feed add JA3 TI feeds `` ja3_feeds `` `` slips',
#  'conf `` Connections port significant rise number attacks listed Port Last year equated attacks ’ almost Slips detects connection port using protocol malicious Multiple reconnection attempts Multiple reconnection attempts Slips established flows reconnections destination IP destination port Zeek alerts default Slips depends Zeek detecting different behaviours example Self-signed certs invalid certs port-scans address scans password guessing Password guessing detected zeek failed ssh logins happen mins scans also detected Slips independently Zeek like ICMP sweeps vertical/horizontal portscans Check PING Sweeps https //stratospherelinuxips',
#  'readthedocs',
#  'io/en/develop/detection_modules',
#  'html ping-sweeps section info SMTP login bruteforce Slips alerts invalid SMTP login attempts occurs within Password Guessing Password guessing detected using ethods slips ',
#  ' Zeek engine failed ssh logins happen mins slips failed ssh logins happen tiemwindow DGA DNS server fails resolve domain responds back NXDOMAIN code detect DGA Slips count amount NXDOMAINs met DNS traffic source IP alert NXDOMAINs Every ',
#  '',
#  ' etc slips generates evidence Connection multiple ports Slips encounters connection specific IP specific port scans previous connections looking connection to/from IP using different port alerts finding connections IP Malicious SSL certificates Slips uses SSL certificates sha1 hashes detect C C servers Slips supports SSL feeds shipped Abuse',
#  'ch feed malicious SSL hashes default add SSL feeds `` ssl_feeds `` `` slips',
#  'conf `` Pastebin downloads Slips detects downloads pastebin using SSL HTTP alerts downloaded file pastebin exceeds bytes value customized slips',
#  "conf changing `` pastebin_download_threshold `` Slips detects pastebin download SSL connection may take hours Young Domains Slips uses whois python library get creation date every domain met dns flows domain age days slips sets alert domains supported list supported TLDs '",
#  "ac_uk '",
#  "at '",
#  "br '",
#  "cl '",
#  "co_il '",
#  "com_tr '",
#  "download '",
#  "education '",
#  "fr '",
#  "id_ '",
#  "info '",
#  "is_ '",
#  "kz '",
#  "me '",
#  "name '",
#  "net '",
#  "nyc '",
#  "org '",
#  "pharmacy '",
#  "press '",
#  "rest '",
#  "ru_rf '",
#  "security '",
#  "site '",
#  "tech '",
#  "tel '",
#  "tickets '",
#  "trade '",
#  "ua '",
#  "video '",
#  'work Bad SMTP logins Slips uses zeek detect SMTP connections zeek detects bad smtp login logs smtp',
#  'log slips reads file sets evidence SMTP bruteforce Slips detects SMTP bruteforce bad SMTP logins happen within seconds -- every generated evidence Slips gathers much info malicious IP prints alert instead alerts saying Detected SSL certificate validation failed certificate expired Destination IP Slips gathers hostname SNI rDNS available data IP get alert saying Detected SSL certificate validation failed certificate expired Destination IP GOOGLE US SNI rDNS prg03s01-in-f70',
#  '1e100',
#  'net DNS ARPA Scans Whenever slips sees new domain dns',
#  "log domain ends '",
#  'in-addr',
#  "arpa ' slips keeps trach domain source IP made DNS request source IP seen ARPA queries within seconds slips generates ARPA scan detection SSH version changing Zeek logs used software software versions software",
#  'log slips knows file software used different IPs like whether SSH : CLIENT HTTP : BROWSER HTTP : SERVER slips detects SSH client SSH server stores IP SSH versions used database whenever slips sees IP using another SSH version compares stored SSH versions current SSH versions different slips generates alert Incompatible CN Zeek logs Certificate CN ssl',
#  'log slips enccounters cn claims belong Slips supported orgs Google Microsoft Apple Twitter Slips checks destination address destination server name belongs org slips generates alert Weird HTTP methods Slips uses zeek weird',
#  'log zeek logs weird HTTP methods seen http',
#  'log weird HTTP method slips detects well Non-SSL connections port Slips detects established connections port using HTTP using zeek conn',
#  "log flows slips finds flow using destination port 'service field conn",
#  "log n't set 'ssl alerts Non-HTTP connections port Slips detects established connections port using SSL using zeek conn",
#  "log flows slips finds flow using destination port 'service field conn",
#  "log n't set 'http alerts Connection private IPs Slips detects private IP connected another private IP threat level info skips alert DNS connection port UDP gateway Connection private IPs outside current local network Slips detects currently used local network alerts find connection to/from private IP n't belong example currently used local network slips sees forged packet going alert High entropy DNS TXT answers Slips check every DNS answer TXT record high entropy strings Encoded encrypted strings entropy higher equal detected using shannon entropy alerted slips entropy threshold changed slips",
#  'conf changing value `` entropy_threshold `` Devices changing IPs Slips stores MAC new IP sees conn',
#  'log every source address conn',
#  'log slips checks MAC used another IP alerts `` Device changing IPs `` Features Section contain list features detections listed flowalerts section https //stratospherelinuxips',
#  'readthedocs',
#  'io/en/develop/flowalerts',
#  'html detection modules https //stratospherelinuxips',
#  'readthedocs',
#  'io/en/develop/detection_modules',
#  'html detection-modules section brief description slips works Flow Alerts Module module flow alerts several behavioral techniques detect attacks analyzing content flow alone detection techniques Long connections Successful SSH connections Connections without DNS resolution DNS resolutions IPs never used Connections unknown ports Data exfiltration Malicious JA3 hashes Connections port Multiple reconnection attempts Alerts Zeek Self-signed certs invalid certs port-scans address scans password guessing DGA Connection multiple ports Malicious SSL certificates Young domains Bad SMTP logins SMTP login bruteforce DNS ARPA Scans Multiple SSH versions Incompatible CN Weird HTTP methods Non-SSL connections port Non-HTTP connections port Connection private IPs Connection private IPs outside current local network High entropy DNS TXT answers Devices changeing IPs SSH version changing details detection follows Long Connections Detect connections long except multicast connections defualt connection considered long exceeds seconds Minutes threshold changed `` config/slips',
#  'conf `` changing value `` long_connection_threshold `` Incompatible CN Zeek logs Certificate CN ssl',
#  'log slips enccounters cn claims belong Slips supported orgs Google Microsoft Apple Twitter Slips checks destination address destination server name belongs org slips generates alert High entropy DNS TXT answers Slips check every DNS answer TXT record high entropy strings Encoded encrypted strings entropy higher equal detected using shannon entropy alerted slips entropy threshold changed slips',
#  'conf changing value `` entropy_threshold `` Devices changing IPs Slips stores MAC new IP sees conn',
#  'log every source address conn',
#  "log slips checks MAC used another IP alerts `` Device changing IPs `` SMTP login bruteforce Slips alerts invalid SMTP login attempts occurs within Connection private IPs Slips detects private IP connected another private IP threat level info skips alert DNS connection port UDP gateway Connection private IPs outside current local network Slips detects currently used local network alerts find connection to/from private IP n't belong example currently used local network slips sees forged packet going alert Weird HTTP methods Slips uses zeek weird",
#  'log zeek logs weird HTTP methods seen http',
#  'log weird HTTP method slips detects well Non-SSL connections port Slips detects established connections port using HTTP using zeek conn',
#  "log flows slips finds flow using destination port 'service field conn",
#  "log n't set 'ssl alerts Non-HTTP connections port Slips detects established connections port using SSL using zeek conn",
#  "log flows slips finds flow using destination port 'service field conn",
#  "log n't set 'http alerts Connections without DNS resolution detect connections done without previous DNS resolution idea connection without DNS resolution slightly suspicious Slips runs capturing packets directly network device opposed example PCAP file detection ignore connections happen first minute operation Slips times Slips started computer already running many DNS connections already done waiting minutes decreases amount False Positives detection ignore certain IP addresses connection without DNS ok exceptions Private IPs Localhost IPs Reserved IPs including super broadcast IPv6 local-link IPs Multicast IPs Broadcast IPs private Well known organizations DNS resolutions well known orgs might done using DoH case slips n't know DNS resolution resolved domain wo n't dns",
#  "log simply ignore alerts time well known org facebook apple google twitter microsoft Slips uses lists organizations info IPs IP ranges domains ASNs stored `` slips_files/organizations_info `` check whether IP/domain flow belong known org Slips n't detect 'connection without DNS running interface except done instance IP check DoH section https //stratospherelinuxips",
#  'readthedocs',
#  'io/en/develop/detection_modules',
#  'html detect-doh docs info slips detects DoH Successful SSH connections Slips detects successful SSH connections using ways Using Zeek Zeek logs successful SSH connection ssh',
#  'log default bytes sent SSH connection bytes DNS resolutions without connection detect DNS resolutions connection done resolution without usage slightly suspicious domains excepted reverse DNS resolutions using in-addr',
#  'arpa domain ',
#  'local domains wild card domain Subdomains cymru',
#  'com since used ipwhois library get ASN IP range Ignore WPAD domain Windows Ignore domains without TLD Chrome test domains Connection unknown ports Slips list known ports located `` slips_files/ports_info/ports_used_by_specific_orgs',
#  'csv `` also list ports belong specific organization `` slips_files/ports_info/ports_used_by_specific_orgs',
#  "csv `` example even though n't well known port Apple uses Apple Push Notification Service APNS port n't files considered unknown Slips Example Spyware uses custom ports hermit https //www",
#  'lookout',
#  "com/blog/hermit-spyware-discovery using ports Data exfiltration Slips generate 'possible data exfiltration alerts number uploaded files IP exceeds MBs number MBs modified editting value `` data_exfiltration_threshold `` `` config/slips",
#  'conf `` Malicious JA3 JA3s hashes Slips uses JA3 hashes detect C C servers JA3s infected clients JA3 Slips shipped ’ zeek scripts add JA3 JA3s fingerprints SSL log files generated zeek Slips supports JA3 feeds addition different threat intelligence feeds JA3 feeds contain JA3 fingerprints identified malicious JA3 threat intelligence feed used Slips Abuse',
#  'ch JA3 feed add JA3 TI feeds `` ja3_feeds `` `` config/slips',
#  'conf `` Connections port significant rise number attacks listed Port Last year equated attacks ’ almost Slips detects connection port using protocol malicious Multiple reconnection attempts Multiple reconnection attempts Slips established flows reconnections destination IP Zeek alerts default Slips depends Zeek detecting different behaviours example Self-signed certs invalid certs port-scans address scans password guessing scans also detected Slips independently Zeek like ICMP sweeps vertical/horizontal portscans Check section info todo DGA DNS server fails resolve domain responds back NXDOMAIN code detect DGA Slips count amount NXDOMAINs met DNS traffic source IP alert NXDOMAINs Every ',
#  '',
#  ' etc slips generates evidence Connection multiple ports Slips encounters connection specific IP specific port scans previous connections looking connection to/from IP using different port alerts finding connections IP Malicious SSL certificates Slips uses SSL certificates sha1 hashes detect C C servers Slips supports SSL feeds shipped Abuse',
#  'ch feed malicious SSL hashes default add SSL feeds `` ssl_feeds `` `` config/slips',
#  "conf `` Young Domains Slips uses whois python library get creation date every domain met dns flows domain age days slips sets alert domains supported list supported TLDs '",
#  "ac_uk '",
#  "at '",
#  "br '",
#  "cl '",
#  "co_il '",
#  "com_tr '",
#  "download '",
#  "education '",
#  "fr '",
#  "id_ '",
#  "info '",
#  "is_ '",
#  "kz '",
#  "me '",
#  "name '",
#  "net '",
#  "nyc '",
#  "org '",
#  "pharmacy '",
#  "press '",
#  "rest '",
#  "ru_rf '",
#  "security '",
#  "site '",
#  "tech '",
#  "tel '",
#  "tickets '",
#  "trade '",
#  "ua '",
#  "video '",
#  'work Bad SMTP logins Slips uses zeek detect SMTP connections zeek detects bad smtp login logs smtp',
#  'log slips reads file sets evidence SMTP bruteforce Slips detects SMTP bruteforce bad SMTP logins happen within seconds -- every generated evidence Slips gathers much info malicious IP prints alert instead alerts saying Detected SSL certificate validation failed certificate expired Destination IP Slips gathers hostname SNI rDNS available data IP get alert saying Detected SSL certificate validation failed certificate expired Destination IP GOOGLE US SNI rDNS prg03s01-in-f70',
#  '1e100',
#  'net DNS ARPA Scans Whenever slips sees new domain dns',
#  "log domain ends '",
#  'in-addr',
#  "arpa ' slips keeps trach domain source IP made DNS request source IP seen ARPA queries within seconds slips generates ARPA scan detection SSH version changing Zeek logs used software software versions software",
#  'log slips knows file software used different IPs like whether SSH : CLIENT HTTP : BROWSER HTTP : SERVER slips detects SSH client SSH server stores IP SSH versions used database whenever slips sees IP using another SSH version compares stored SSH versions current SSH versions different slips generates alert Detection modules Slips behavioral-based IPS uses machine learning detect malicious behaviors network traffic modular software extended Slips run spawns several child processes manage I/O profile attackers run detection modules describe detection modules run traffic detect malicious behaviour Modules Python-based files allow developer extend functionality Slips process analyze data perform additional detections store data Redis modules consume Currently Slips following modules style table font-family arial sans-serif border-collapse collapse width td th border solid dddddd text-align left padding tr nth-child even background-color dddddd /style table tr th Module /th Description /th th Status /th /tr tr td ARP Detection /td td Finds ARP scans MITM ARP local networrk ',
#  ' td ✅ /td /tr tr td Exporting /td td Exports Slips alerts Slack servers STIX servers ',
#  ' /td td ✅ /td /tr tr td IP_Info /td td Finds Geolocation country ASN IP address ',
#  ' /td td ✅ /td /tr tr td CESNET /td td Send receive alerts warden servers ',
#  ' /td td ✅ /td /tr tr td RiskIQ /td td Finds information RiskIQ passive DNS domains downloads Threat Intelligence feed ',
#  ' td ✅ /td /tr tr td Update /td td Takes care downloading files used Slips need update stores checks ETags remote files know changed configured update file different frequency importantly updates Threat Intelligence feeds ',
#  ' /td td ✅ /td /tr tr td Threat Intelligence /td td Checks domain IP included Threat Intelligence feeds Domains include DNS requests DNS replies HTTP hostnames TLS SNI IPs include source destination IPs IPv4 IPv6 /td td ✅ /td /tr tr td https /td td training test RandomForest detect malicious https flows /td td ⏳ /td /tr tr td port scan detector /td td detects Horizontal Vertical port scans /td td ✅ /td /tr tr td timeline /td td creates timeline happened network based flows type data available /td td ✅ /td /tr tr td rnn-cc-detection /td td detects command control channels using recurrent neural network stratosphere behavioral letters /td td ✅ /td /tr tr td VirusTotal /td td module lookup IP address VirusTotal /td td ✅ /td /tr tr td flowalerts /td td Finds malicious behaviours analyzing flow detects self-signed certificates TLS certificates validation failed vertical port scans detected Zeek contrary detected Slips horizontal port scans detected Zeek contrary detected Slips password guessing SSH detected Zeek long connection successful ssh /td td ✅ /td /tr tr td leak_detector /td td module detect leaks data traffic using YARA rules /td td ✅ /td /tr tr td ARP /td td module check ARP attacks ARP traffic /td td ✅ /td /tr tr td http_analyzer /td td module analyze HTTP traffic ',
#  ' td ✅ /td /tr tr td blocking /td td Blocks alerted IPs Linux iptables Firewall ',
#  ' /td td ✅ /td /tr tr td flowmldetection /td td module detect malicious flows using machine learning /td td ✅ /td /tr /table Virustotal Module module used lookup IPs domains URLs virustotal use need add virustotal API key `` config/vt_api_key `` RiskIQ Module module used get different information passive DNS IoCs etc RiskIQ https //www',
#  'riskiq',
#  'com/ use module RiskIQ email API key stored `` config/RiskIQ_credentials `` format file following `` example domain',
#  'com e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855 `` hash character API Key path file modified changing `` RiskIQ_credentials_path `` parameter `` config/slips',
#  'conf `` Leak Detection Module module runs pcaps uses YARA rules detect leaks add YARA rule `` modules/leak_detector/yara_rules/rules `` automatically compiled stored `` modules/leak_detector/yara_rules/compiled `` matched every pcap Blocking Module enable blocking slips start slips `` -p `` flag feature supported linux using iptables natively using docker Exporting Alerts Module Slips supports exporting alerts systems using different modules ExportingAlerts CESNET sharing etc supported systems Slack TAXII Servers STIX format Warden servers IDEA JSON format Logstash Refer exporting section docs https //stratospherelinuxips',
#  'readthedocs',
#  'io/en/develop/exporting',
#  'html detailed instructions export Flowalerts Module module responsible detecting malicious behaviours traffic Refer Flowalerts section docs https //stratospherelinuxips',
#  'readthedocs',
#  'io/en/develop/flowalerts',
#  'html detailed explanation Slips detects detects Disabled alerts Slips detections turned default configure alerts want enable/disable `` config/slips',
#  "conf `` Slips support disabling unwanted alerts simply add detection want disable `` disabled_detections `` list slips generate alerts type example disabled_detections MaliciousJA3 DataExfiltration SelfSignedCertificate Supported detections ARPScan ARP-outside-localnet UnsolicitedARP MITM-ARP-attack SSHSuccessful LongConnection MultipleReconnectionAttempts ConnectionToMultiplePorts InvalidCertificate UnknownPort Port0Connection ConnectionWithoutDNS DNSWithoutConnection MaliciousJA3 DataExfiltration SelfSignedCertificate PortScanType1 PortScanType2 Password_Guessing MaliciousFlow SuspiciousUserAgent multiple_google_connections NETWORK_gps_location_leaked Command-and-Control-channels-detection ThreatIntelligenceBlacklistDomain ThreatIntelligenceBlacklistIP MaliciousDownloadedFile DGA MaliciousSSLCert YoungDomain MultipleSSHVersions DNS-ARPA-Scan SMTPLoginBruteforce BadSMTPLogin IncompatibleUserAgent ICMP-Timestamp-Scan ICMP-AddressScan ICMP-AddressMaskScan Threat Intelligence Module Slips complex system deal Threat Intelligence feeds Slips supports different kinds IoCs TI feeds IPs IP ranges domains JA3 hashes SSL hashes File hashes URLs n't supported Matching IPs Slips gets every IP find network tries see blacklist match found generates evidence exact match found searches Blacklisted ranges taken different TI feeds Matching Domains Slips gets every domain find network tries see blacklist domains currently taken DNS requests DNS responses HTTP host names TLS SNI domain found verified downloaded list domains blacklists defined `` ti_files `` configuration file `` config/slips",
#  'conf `` exact match found evidence generated exact match found Slips verifies verified domain subdomain domain blacklist example domain traffic _here',
#  'testing',
#  'com_ Slips first checks exact domain _here',
#  'testing',
#  'com_ blacklist match checks domain _testing',
#  'com_ blacklists Matching JA3 Hashes Every time Slips encounters TLS flow compares JA3 JA3s feeds malicious JA3 alerts ’ match Slips shipped Abuse',
#  'ch JA3 feed default add SSL feed appending file defined `` ja3_feeds `` key `` config/slips',
#  'conf `` default `` config/JA3_feeds',
#  'csv `` Matching SSL SHA1 Hashes Every time Slips encounters SSL flow tries get certificate hash zeek ssl',
#  'log compares hash list blacklisted SSL certificates Slips shipped Abuse',
#  'ch SSL feed default add SSL feed appending file defined `` ssl_feeds `` key `` config/slips',
#  'conf `` default `` config/SSL_feeds',
#  'csv `` Local Threat Intelligence files Slips local file adding IoCs located `` config/local_data_files/own_malicious_iocs',
#  'csv `` default path changed changing `` download_path_for_local_threat_intelligence `` `` config/slips',
#  'conf `` format file `` IP address `` `` Threat level `` `` Description `` Threat level available options info low medium high critical Refer architecture section docs https //stratospherelinuxips',
#  'readthedocs',
#  'io/en/develop/architecture',
#  'html detailed explanation Slips threat levels Example `` `` `` high `` `` Simda CC `` `` bncv00',
#  'no-ip',
#  'info `` `` critical `` `` Variant',
#  'Zusy `` Local JA3 hashes Slips local file adding JA3 hashes located `` config/local_data_files/own_malicious_JA3',
# ...
#  'google',
#  'com/go/go1',
#  '18',
#  'linux-amd64',
#  'tar',
#  'gz -- output go',
#  'tar',
#  'gz rm -rf /usr/local/go tar -C /usr/local -xzf go',
#  'tar',
#  'gz export PATH= PATH /usr/local/go/bin `` build pigeon installed slips submodules using `` git clone -- recurse-submodules -- remote-submodules https //github',
#  'com/stratosphereips/StratosphereLinuxIPS `` build pigeon using `` cd p2p4slips go build `` installed Slips without submodules download build pigeon using `` git submodule init git submodule update cd p2p4slips go build `` p2p binary `` p2p4slips/ `` dir slips able find NOTE installed p2p4slips submodule anywhere slips main directory remember add PATH using following commands `` echo `` export PATH= PATH /path/to/StratosphereLinuxIPS/p2p4slips/ `` ~/',
#  'bashrc source ~/',
#  'bashrc `` Usage Slips P2P module disabled default Slips enable change `` use_p2p=no `` `` use_p2p=yes `` `` config/slips',
#  "conf `` P2P available running slips local network using interface -i interface n't anything particular P2P module work enable Slips 1- Automatically find peers network remember even go offline days 2- Ask group peers network think IoC 3- Group answers give Slips aggregated balanced normalized view network opinion IoC 4- Send blame reports whole network attackers 5- Receive blame reports attackers network balanced trust model 6- Keep trust score peer varies time based interactions quality data shared Project sections project built Slips module uses Redis communication Integration Slips seamless easy adjust module use IPSs following code related Dovecot Slips Intrusion Prevention System Dovecot module module Slips Pigeon P2P wrapper written golang Dovecot experiments framework evaluating trust models optional Dovecot experiments Experiments essential module whole project runs fine without useful development new trust models modelling behavior P2P network use experiments clone https //github",
#  'com/stratosphereips/p2p4slips-experiments repository modules/p2ptrust/testing/experiments experiments run independently outside Slips start processes needed including relevant parts Slips code needs placed inside module necessary dependencies accessible best design choice simplest quick solution works Slips interacts slips peers following purposes Blaming IPs slips finds IP malicious given enough evidence blocks tells peers IP malicious need block called sending blame report Receiving Blames slips receives blame report network means slips instance th network set evidence IP letting peers know Slips generates evidence reported IP takes report consideration deciding block attacker IP Asking network IP Whenever slips sees new IP asks peers waits seconds reply network replies score confidence IP higher score malicious IP get score IP store database alert score IP threat level=info Answering network request IP asked ip slips shares score confidence requesting peer scores generated slips saved database Logs Slips contains minimal log file reports received peers peer updates `` output/p2p_reports',
#  'log `` detailed p2p logs example peer ping pongs peer lists errors etc enable p2p',
#  'log slips',
#  'conf setting `` create_p2p_logfile `` `` yes `` `` p2p',
#  'log `` available output dir Slips rotates p2p',
#  'log every day default keeps logs past day Limitations slips supports requests blames IPs Domains URLs hashes supported easily added future TLDR Slips shares scores confidence numbers generated slips IPs network private information shared Detection modules Slips behavioral-based IPS uses machine learning detect malicious behaviors network traffic modular software extended Slips run spawns several child processes manage I/O profile attackers run detection modules describe detection modules run traffic detect malicious behaviour Modules Python-based files allow developer extend functionality Slips process analyze data perform additional detections store data Redis modules consume Currently Slips following modules style table font-family arial sans-serif border-collapse collapse width td th border solid dddddd text-align left padding tr nth-child even background-color dddddd /style table tr th Module /th Description /th th Status /th /tr tr td ARP /td td Finds ARP scans MITM ARP local networrk ',
#  ' td ✅ /td /tr tr td Exporting Alerts /td td Exports Slips alerts Slack servers STIX servers ',
#  ' /td td ✅ /td /tr tr td IP Info /td td Finds Geolocation country ASN IP address ',
#  ' /td td ✅ /td /tr tr td CESNET /td td Send receive alerts warden servers ',
#  ' /td td ✅ /td /tr tr td Risk IQ /td td Finds information RiskIQ passive DNS domains downloads Threat Intelligence feed ',
#  ' td ✅ /td /tr tr td Update Manager /td td Takes care downloading files used Slips need update stores checks ETags remote files know changed configured update file different frequency importantly updates Threat Intelligence feeds ',
#  ' /td td ✅ /td /tr tr td Threat Intelligence /td td Checks domain IP included Threat Intelligence feeds Domains include DNS requests DNS replies HTTP hostnames TLS SNI IPs include source destination IPs IPv4 IPv6 /td td ✅ /td /tr tr td HTTPS /td td training test RandomForest detect malicious https flows /td td ⏳ /td /tr tr td Port Scan Detector /td td detects Horizontal Vertical port scans /td td ✅ /td /tr tr td Timeline /td td creates timeline happened network based flows type data available /td td ✅ /td /tr tr td RNN C C Detection /td td detects command control channels using recurrent neural network stratosphere behavioral letters /td td ✅ /td /tr tr td VirusTotal /td td module lookup IP address VirusTotal /td td ✅ /td /tr tr td Flow Alerts /td td Finds malicious behaviours analyzing flow detects self-signed certificates TLS certificates validation failed vertical port scans detected Zeek contrary detected Slips horizontal port scans detected Zeek contrary detected Slips password guessing SSH detected Zeek long connection successful ssh /td td ✅ /td /tr tr td Leak Detector /td td module detect leaks data traffic using YARA rules /td td ✅ /td /tr tr td ARP /td td module check ARP attacks ARP traffic /td td ✅ /td /tr tr td HTTP Analyzer /td td module analyze HTTP traffic ',
#  ' td ✅ /td /tr tr td Blocking /td td Blocks alerted IPs Linux iptables Firewall ',
#  ' /td td ✅ /td /tr tr td Flow ML Detection /td td module detect malicious flows using machine learning /td td ✅ /td /tr /table Virustotal Module module used lookup IPs domains URLs virustotal use need add virustotal API key `` config/vt_api_key `` RiskIQ Module module used get different information passive DNS IoCs etc RiskIQ https //www',
#  'riskiq',
#  'com/ use module RiskIQ email API key stored `` config/RiskIQ_credentials `` format file following `` example domain',
#  'com e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855 `` hash character API Key path file modified changing `` RiskIQ_credentials_path `` parameter `` config/slips',
#  'conf `` Leak Detection Module module runs pcaps uses YARA rules detect leaks add YARA rule `` modules/leak_detector/yara_rules/rules `` automatically compiled stored `` modules/leak_detector/yara_rules/compiled `` matched every pcap Blocking Module enable blocking slips start slips `` -p `` flag feature supported linux using iptables Exporting Alerts Module Slips supports exporting alerts systems using different modules ExportingAlerts CESNET sharing etc supported systems Slack TAXII Servers STIX format Warden servers suricata-like JSON format Logstash Refer exporting section docs https //stratospherelinuxips',
#  'readthedocs',
#  'io/en/develop/exporting',
#  'html detailed instructions export Flowalerts Module module responsible detecting malicious behaviours traffic Refer Flowalerts section docs https //stratospherelinuxips',
#  'readthedocs',
#  'io/en/develop/flowalerts',
#  'html detailed explanation Slips detects detects Disabled alerts Slips detections turned default configure alerts want enable/disable `` config/slips',
#  "conf `` Slips support disabling unwanted alerts simply add detection want disable `` disabled_detections `` list slips generate alerts type example disabled_detections MaliciousJA3 DataExfiltration SelfSignedCertificate Supported detections ARPScan ARP-outside-localnet UnsolicitedARP MITM-ARP-attack SSHSuccessful LongConnection MultipleReconnectionAttempts ConnectionToMultiplePorts InvalidCertificate UnknownPort Port0Connection ConnectionWithoutDNS DNSWithoutConnection MaliciousJA3 DataExfiltration SelfSignedCertificate VerticalPortscan HorizontalPortscan Password_Guessing MaliciousFlow SuspiciousUserAgent multiple_google_connections NETWORK_gps_location_leaked Command-and-Control-channels-detection ThreatIntelligenceBlacklistDomain ThreatIntelligenceBlacklistIP MaliciousDownloadedFile DGA MaliciousSSLCert YoungDomain MultipleSSHVersions DNS-ARPA-Scan SMTPLoginBruteforce BadSMTPLogin IncompatibleUserAgent ICMP-Timestamp-Scan ICMP-AddressScan ICMP-AddressMaskScan Threat Intelligence Module Slips complex system deal Threat Intelligence feeds Slips supports different kinds IoCs TI feeds IPs IP ranges domains JA3 hashes SSL hashes File hashes URLs n't supported TI feeds Besides searching TI files every IP/domain Slips encounters also uses following websites threat intelligence URLhaus url seen http",
#  'log downloaded file seen files',
#  'log Spamhaus IP lookups Circl',
#  'lu hash lookups downloaded file Matching IPs Slips gets every IP find network DNS answers HTTP destination IPs SSH destination IPs etc tries see blacklist match found generates evidence exact match found searches Blacklisted ranges taken different TI feeds Matching Domains Slips gets every domain find network tries see blacklist domains currently taken DNS requests DNS responses HTTP host names TLS SNI domain found verified downloaded list domains blacklists defined `` ti_files `` path configuration file `` config/slips',
#  'conf `` `` config/TI_feeds',
#  'csv `` default exact match found evidence generated exact match found Slips verifies verified domain subdomain domain blacklist example domain traffic _here',
#  'testing',
#  'com_ Slips first checks exact domain _here',
#  'testing',
#  'com_ blacklist match checks domain _testing',
#  'com_ blacklists Matching JA3 Hashes Every time Slips encounters TLS flow compares JA3 JA3s feeds malicious JA3 alerts ’ match Slips shipped Abuse',
#  'ch JA3 feed default add SSL feed appending `` ja3_feeds `` key `` config/slips',
#  'conf `` Matching SSL SHA1 Hashes Every time Slips encounters SSL flow tries get certificate hash zeek ssl',
#  'log compares hash list blacklisted SSL certificates Slips shipped Abuse',
#  'ch SSL feed default add SSL feed appending `` ssl_feeds `` key `` config/slips',
#  'conf `` Matching ASNs Every time Slips sees new IP stores info db example organization RDNs ASN ASN IP matches blacklisted ASN slips alerts Blacklisted ASNs read local TI file `` config/local_data_files/own_malicious_iocs',
#  'csv `` update add Local Threat Intelligence files Slips local file adding IoCs located `` config/local_data_files/own_malicious_iocs',
#  'csv `` default path changed changing `` download_path_for_local_threat_intelligence `` `` config/slips',
#  'conf `` format file `` IP address/IP Range/domain/ASN `` `` Threat level `` `` Description `` Threat level available options info low medium high critical Refer architecture section docs https //stratospherelinuxips',
#  'readthedocs',
#  'io/en/develop/architecture',
#  'html detailed explanation Slips threat levels Example `` `` `` high `` `` Simda CC `` `` bncv00',
#  'no-ip',
#  'info `` `` critical `` `` Variant',
#  'Zusy `` Local JA3 hashes Slips local file adding JA3 hashes located `` config/local_data_files/own_malicious_JA3',
#  'csv `` default format file `` JA3 hash `` `` Threat level `` `` Description `` Threat level available options info low medium high critical Refer architecture section docs https //stratospherelinuxips',
#  'readthedocs',
#  'io/en/develop/architecture',
#  'html detailed explanation Slips threat levels Example `` e7d705a3286e19ea42f587b344ee6865 `` `` medium `` `` Standard tor client `` `` `` `` high `` `` Trickbot Malwar `` Adding remote feed update remote ones regularly list remote threat intelligence files set path `` ti_files `` variable `` config/slips',
#  'conf `` path TI feeds `` config/TI_feeds',
#  'csv `` default add remote threat intelligence feeds variable Supported extensions ',
#  'txt ',
#  'csv ',
#  'netset ipsum feeds ',
#  'intel URL added threat_level tag format url threat_level tag tag category feed e',
#  'g phishing adtrackers etc ',
#  '',
#  ' Threat level available options info low medium high critical Refer architecture section docs https //stratospherelinuxips',
#  'readthedocs',
#  'io/en/develop/architecture',
#  "html detailed explanation Slips threat levels TI files commented using may processed 're still database Use `` `` commenting TI files `` config/slips",
#  'conf `` instead `` `` Commented TI files lines starting completely removed database remote files downloaded path set `` download_path_for_local_threat_intelligence `` default files stored Slips directory `` modules/ThreatIntelligence1/remote_data_files/ `` deleted slips done reading Commenting remote TI feed remote file link wish comment remove database adding line contains feed link `` config/TI_feeds',
#  "csv `` n't use example comment `` bruteforcelogin `` feed following https //lists",
#  'blocklist',
#  'de/lists/bruteforcelogin',
#  "txt medium 'honeypot instead https //lists",
#  'blocklist',
#  'de/lists/bruteforcelogin',
#  'txt medium Update Manager Module make sure Slips date recent IoCs feeds feeds loaded parsed updated periodically automatically Slips every hours requires user interaction hours interval changed changing `` TI_files_update_period `` key `` config/slips',
#  'conf `` Update manager responsible updating remote TI files including SSL JA3 etc default local slips files organization_info ports_info etc cached avoid loading parsing everytime start slips However updated automatically update manager changed disk slips instance allowed using update manager time avoid race conditions IP Info Module IP info module several ways getting information IP address includes ASN Country Geolocation Given MAC Vendor Reverse DNS ASN Slips shipped offline database GeoLite2 `` databases/GeoLite2-ASN',
#  'mmdb `` search ASNs ASN given IP GeoLite2 database try get ASN online using online database using `` ipwhois `` library However reduce amount requests retrieve range IP cache whole range search cache whole range IP module uses ipwhois library ipwhois library gets range IP making connection server `` cymru',
#  'com `` using TXT DNS query DNS server set operating system example get ASN IP see DNS connection asking TXT record domain `` `` Country Geolocation Slips shipped offline database GeoLite2 `` databases/GeoLite2-Country',
#  'mmdb `` search Geolocation Mac Vendors Slips shipped offline database `` databases/macaddress-db',
#  'json `` MAC address vendor mapping Slips updates database default every weeks using following online db https //maclookup',
#  'app/downloads/json-database/get-db t=22-08-19 h=d1d39c52de447a7e7194331f379e1e99f94f35f1 change often db updated changing value `` mac_db_update `` `` config/slips',
#  'conf `` Slips gets MAC address IP dhcp',
#  'log arp',
#  "log searches offline database using OUI vendor n't found offline MAC database Slips tries get MAc using online database https //www",
#  'macvendorlookup',
#  "com offline database updated manually shipped slips find `` databases/ `` dir Slips makes sure n't perform duplicate searches MAC Address online offline Reverse DNS obtained standard in-addr",
#  "arpa DNS request ARP Module module used check ARP attacks network traffic default zeek n't generate log ARP flows Slips shipped zeek scripts enable logging ARP flows `` arp",
#  ...]

# %%
filtered_sentences = []

for sentence in sentences:
    if len(sentence) < 15:
        continue
    filtered_sentences.append(sentence)

# %%
filtered_sentences
# Out:
# ['Contributing contributions welcomed thank taking time contribute project set guidelines contributing development Slips contribute Run Slips report bugs needed features suggest ideas Pull requests solved GitHub issue new feature Pull request new detection module Persistent Git Branches following git branches Slips repository permanent master contains stable version Slips new versions least month develop contains latest unstable version Slips also latest features new features based branch Naming Git branches Pull Requests keep Git history clean facilitate revision contributions ask branches follow concise namings branch-naming patterns follow contributing Slips author-bugfix- pull request branch contains bugfix author-docs- pull request branch contains documentation work author-enhance- pull request branch contains enhancement new feature improvement nonetheless author-feature- pull request branch contains new feature author-refactor- pull request branch contains code refactoring branch base contribution Slips general rule base contributions develop branch Creating pull request Commits Commits follow KISS principle thing well keep simple stupid Commit messages easily readable imperative style `` Fix memory leak ',
#  ' `` `` FixES mem ',
#  " `` Pull Requests developed multiple features and/or bugfixes create separate branches request merges branch PR develop trigger develop Github checks checks run Slips unit tests integration tests locally ubuntu VM docker make sure branch ready merge PRs wo n't merged unless checks pass cleaner code/change/changeset faster merged Beginner tips create PR Slips simple beginner-level steps create PR Slips Clone Slips repo clone checkout origin/develop `` git checkout origin develop `` Create branch develop using name feature name `` git checkout -b yourname feature_name develop `` Change code add feature fix bug etc commit descriptive msg `` git commit -m `` descriptive msg `` `` Test code important step n't open PR code working `` ",
#  '/tests/run_all_tests',
#  "sh `` tests n't pass means need fix something branch Push repo `` git push -u origin yourname feature_name `` Open PR Slips remember set base branch develop List changes PR description IDEs like PyCharm https //www",
#  'com/help/pycharm/work-with-github-pull-requests',
#  'html vscode https //levelup',
#  'com/how-to-create-a-pull-request-on-github-using-vs-code-f03db28308c4 option open PR within IDE ready-to-merge PR contributions guidelines inspired project Snoopy https //raw',
#  'githubusercontent',
#  'com/a2o/snoopy/master/',
#  'github/CONTRIBUTING',
#  'md \ufeff Slips Action demonstrate capabilities Slips give real life malware traffic checking Slips analyses img src= `` https //raw',
#  'githubusercontent',
#  'com/stratosphereips/StratosphereLinuxIPS/develop/docs/images/slips',
#  'gif `` title= `` Slips action `` Saefko RAT provide analysis network traffic RAT06-Saefko download https //mcfp',
#  'cz/publicDatasets/Android-Mischief-Dataset/AndroidMischiefDataset_v2/RAT06_Saefko/ using Slips capture contains different actions done RAT controller e',
#  'g upload file get GPS location monitor files etc ',
#  ' detailed analysis check Kamila Babayeva blog Dissecting RAT Analysis Saefko RAT https //www',
#  'stratosphereips',
#  'org/blog/2021/6/2/dissecting-a-rat-analysis-of-the-saefko-rat analysis know controller IP address f410:3340 d02b b918 victim IP address b877:48ae:9531 fbfc First run slips using following command ',
#  'py -e -f RAT06_Saefko',
#  'pcap First Slips start updating remote TI feeds added slips',
#  'conf img src= `` https //raw',
#  'githubusercontent',
#  'com/stratosphereips/StratosphereLinuxIPS/develop/docs/images/updating_remote_feeds',
#  'png `` title= `` Slips updating remote TI feeds `` make sure Slips date recent IoCs feeds feeds loaded parsed updated periodically automatically Slips every hours Update Manager https //stratospherelinuxips',
#  'io/en/develop/detection_modules',
#  'html update-manager-module requires user interaction Afetr updating slips modules start print PID every successfully started module img src= `` https //raw',
#  'githubusercontent',
#  'com/stratosphereips/StratosphereLinuxIPS/develop/docs/images/modules_starting',
#  'png `` title= `` Slips modules starting `` see get alert saefko_first_alert',
#  'png Alerts printed evidence module Slips detected IP b877:48ae:9531 fbfc infected due evidence See difference alerts evidence https //stratospherelinuxips',
#  'io/en/develop/architecture',
#  'html Slips splits detections timewindows time window hour long default contains dozens features computed connections start time window IP behaves maliciously PM marked infected hour next hour malicious behaviour occurs slips treat traffic normal explains start stop timestamps alert start 2021-04-10T16:44:43',
#  '285478+02:00 stop 2021-04-10T17:44:43',
#  '285478+0200 period timewindow IP behaving maliciously difference infected normal timewindows shown better kalispo https //stratospherelinuxips',
#  'io/en/develop/usage',
#  'html reading-the-output user interface start another terminal using ',
#  'sh img src= `` https //raw',
#  'githubusercontent',
#  'com/stratosphereips/StratosphereLinuxIPS/develop/docs/images/kalispo_infected_tw',
#  'png `` title= `` Kalipso infected timewindow `` p Figure /p see IP b877:48ae:9531 fbfc infected timewindow1 marked red behaving normally timewindow0 colored green see flows done IP infected timewindow kalipso pressing enter timewindow1 img src= `` https //raw',
#  'githubusercontent',
#  'com/stratosphereips/StratosphereLinuxIPS/develop/docs/images/expanding_infected_timewindow',
#  'png `` title= `` Kalipso expanding infected timewindow `` bottom box kalipso scroll though evidence se slips detected evidence printed Figure see following detections evidence Detected Malicious JA3 source address b877:48ae:9531 fbfc CESNET z',
#  "o description Tofsee 'malicious JA3 fingerprint client part SSL certificate indicates source IP b877:48ae:9531 fbfc infected Tofsee malware family Slips also detected connection database SSL certificate validation failed certificate expired Destination IP dead d8f :1 SNI experimentsas",
#  'com RAT analysis know web hosting service used C C server Slips also detected Connection unknown destination port destination IP a191 : fff:1 Connection unknown destination port destination IP APK list IRC servers shown RAT analysis know phone connects port different IRC servers receive malicious commands rDNS server also printed alert open',
#  "net machine learning module rnn-cc-detection detected C C server using recurrent neural network Detected C C channel destination IP port score Slips also detected Possible DGA domain scanning failed resolve domains detections evidence accumulated resulted alert view evidence slips detected including n't enough generate alert cat output/alerts",
#  'log img src= `` https //raw',
#  'githubusercontent',
#  'com/stratosphereips/StratosphereLinuxIPS/develop/docs/images/alerts_log',
#  'png `` title= `` Slips updating remote TI feeds `` Slips also another log file JSON format easily parsed exported See exporting section https //stratospherelinuxips',
#  'io/en/develop/exporting',
#  'html documentation generated alerts file follow CESNET IDEA0 format https //idea',
#  'cz/en/index cat output/alerts',
#  'json -- Emotet analysing several Emotet PCAPs starting infection Trickbot Qakbot malwares dropped captures contain different actions done Emotet trickbot controller detailed analysis check Paloalto blog Examining Emotet Infection Traffic https //unit42',
#  'paloaltonetworks',
#  'com/wireshark-tutorial-emotet-infection/ text=Example Emotet infection analysing Emotet PCAP download https //github',
#  'com/pan-unit42/wireshark-tutorial-Emotet-traffic/blob/main/Example-1-2021-01-06-Emotet-infection',
#  'zip password infected running Slips PCAP ',
#  'py -f Example-1-2021-01-06-Emotet-infection',
#  'pcap get following alerts img src= `` https //raw',
#  'githubusercontent',
#  'com/stratosphereips/StratosphereLinuxIPS/develop/docs/images/emotet_alerts',
#  'png `` title= `` Slips generated Emotet alerts `` reconnection attemps shown analysis img src= `` https //unit42',
#  'paloaltonetworks',
#  'com/wp-content/uploads/2021/01/word-image-45',
#  'jpeg `` title= `` Slips generated Emotet alerts `` detected Slips following evidence Detected connection without DNS resolution IP Detected Multiple reconnection attempts Destination IP IP Trickbot Analyzing next PCAP download https //github',
#  'com/pan-unit42/wireshark-tutorial-Emotet-traffic/blob/main/Example-4-2021-01-05-Emotet-infection-with-Trickbot',
#  'zip contains Trickbot traffic password infected Running slips pcap ',
#  'py -f Example-4-2021-01-05-Emotet-infection-with-Trickbot',
#  'pcap img src= `` https //raw',
#  'githubusercontent',
#  'com/stratosphereips/StratosphereLinuxIPS/develop/docs/images/trickbot',
#  'png `` title= `` Slips generated Trickbot alerts `` Slips detects signed SSL certificate trickbot IP associated data exfiltration Detected SSL certificate validation failed self signed certificate Destination IP Slips also detected Detected connection without DNS resolution IP ',
#  ' Detected Connection unknown destination port destination IP Qakbot Analyzing next PCAP download https //github',
#  'com/pan-unit42/wireshark-tutorial-Emotet-traffic/blob/main/Example-5-2020-08-18-Emotet-infection-with-Qakbot',
#  'zip contains Qakbot traffic password infected Running slips pcap ',
#  'py -f Example-5-2020-08-18-Emotet-infection-with-Qakbot',
#  'pcap img src= `` https //raw',
#  'githubusercontent',
#  'com/stratosphereips/StratosphereLinuxIPS/develop/docs/images/qakbot',
#  "png `` title= `` Slips generated Trickbot alerts `` Slips detected victim infected Qakbo using JA3 Detected Malicious JA3 source address description Quakbot 'malicious Detected Malicious JA3 source address description Gozi 'malicious also see Domain generation algorithm detection victim Detected possible DGA domain scanning failed resolve domains expired certificate samaritantec",
#  'com domain reported hosting Emotet binary date https //urlhaus',
#  'ch/url/436011/ Detected SSL certificate validation failed certificate expired Destination IP SNI samaritantec',
#  'com Slips detected Detected C C channel destination IP port score etected connection without DNS resolution IP CHARTER-20115 rDNS 071-080-066-107',
#  'com quick search virustotal shows IP associated qakbot https //www',
#  'com/cyber-security-blog/qbot-delivery-method-malware-analysis/ port scan Detected horizontal port scan port unique dst IPs Tot pkts Threat Level medium -- DroidJack v4',
#  '4 RAT Running Slips DroidJack v4',
#  '4 RAT download https //mcfp',
#  'cz/publicDatasets/Android-Mischief-Dataset/AndroidMischiefDataset_v1/DroidJack',
#  'zip password infected capture contains different actions done RAT controller e',
#  'g upload file get GPS location monitor files etc ',
#  ' detailed analysis check Kamila Babayeva blog Analysis DroidJack v4',
#  '4 RAT network traffic https //www',
#  'stratosphereips',
#  'org/blog/2021/1/22/analysis-of-droidjack-v44-rat-network-traffic analysis know controller IP address victim IP address running slips PCAP ',
#  'pcap get following alerts img src= `` https //raw',
#  'githubusercontent',
#  'com/stratosphereips/StratosphereLinuxIPS/develop/docs/images/droidjack_alert',
#  'png `` title= `` Slips generated DroidJack alerts `` Slips detected connection C C server using unknown port Detected Connection unknown destination port destination IP Slips also detected reconnection attemps made victim C C server Multiple reconnection attempts Destination IP IP Slips also detects connections without resolutions due wide usages among malware check internet connectivity get commands fro C C servers Detected connection without DNS resolution IP CESNET z',
#  ' rDNS dhcp-83-253',
#  'cz indentification SNI rDNS IP available printed every evidence generated Slips Threat intelligence feed Abuse',
#  'ch https //sslbl',
#  'ch/blacklist/ja3_fingerprints',
#  "csv detected malicious JA3 indicating victim infected Detected Malicious JA3 source address description 'malicious machine learning models detected C C server Detected C C channel destination IP port score Slips creates profile per IP appeared traffic profile contains flows sent IP flow described specific letter description found https //www",
#  'stratosphereips',
#  'org/stratosphere-testing-framework Considering Slips detects C C channel Slips ’ machine learning module called LSTM detecting C C channel shown img src= `` https //images',
#  'squarespace-cdn',
#  'com/content/v1/5a01100f692ebe0459a1859f/1611308467564-L34N8ANZOO8WUIO9OT7O/image2',
#  'png `` title= `` Behavioral model connection phone C C `` Slips detect periodic connection LSTM module focuses TCP behavioral model connections shown conclude model periodic connections small size img src= `` https //images',
#  'squarespace-cdn',
#  'com/content/v1/5a01100f692ebe0459a1859f/1611308530585-BKXFXAQXGFIPXPRLSSVF/image5',
#  'png `` title= `` Behavioral model created Slips connection phone server using `` Exporting Slips supports exporting alerts systems using different modules ExportingAlerts CESNET sharing etc supported systems Slack TAXII Servers STIX format Warden servers IDEA JSON format Logstash Slack Slips uses WebHook method send data Slack info https //api',
#  'com/messaging/webhooks export slack channel need Create new application slack see https //api',
#  'com/apps/ Remember applications seen per user users Slack see application probably Activate Incoming Webhooks creating app Create Incoming Webhook channel want send messages Go Slack copy channel ID channel going channel clicking channel name ID bottom pop-up window need give app correct scope Slips needs write access channel Go app Slack https //api',
#  "com/apps navigation menu choose OAuth Permissions feature Scroll Scopes section pick channels read chat write drop menu Scroll back top page look button says Install App Workspace Reinstall App 've done Click 'OAuth Permissions page copy User OAuth Token look something like 'xoxb-nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn lot letters Put bot OAuth token file `` config/slack_bot_token_secret `` need add new app channel Slack clicking bot name messae add integration channel click app channel Alternatively add bot channel going channel `` /invite bots_name `` Edit config/slips",
#  'conf file put slack export\\_to variable add channel name want send exporting_alerts export_to slack slack_channel_name SlipsAlertsChannel STIX want export alerts TAXII server using STIX format change `` export_to `` variable export STIX Slips automatically generate `` STIX_data',
#  'json `` containing alerts detects ExportingAlerts export_to stix add TAXII server details following variables `` TAXII_server `` link TAXII server `` port `` port used `` use_https `` use https `` discovery_path `` `` inbox_path `` contain URIs full urls example `` python discovery_path /services/discovery-a inbox_path /services/inbox-a `` `` collection_name `` collection server want push STIX data `` push_delay `` time wait pushing STIX data server seconds used slips running non-stop e',
#  'g -i `` taxii_username `` TAXII server user credentials `` taxii_password `` TAXII server user password `` jwt_auth_path `` auth path JWT based authentication used usually /management/auth use get token TAXII server remote server set `` port `` running file Slips export server analysis done running interface Slips export server every push_delay seconds default JSON format default Slips logs alerts `` output/alerts',
#  'json `` CESNET IDEA0 format https //idea',
#  'cz/en/index also JSON format CESNET Sharing Slips supports exporting alerts warden servers well importing alerts enable exporting set `` receive_alerts `` `` yes `` config/slips',
#  'conf default configuration file path specified `` configuration_file `` variable `` config/slips',
#  'conf `` default path `` config/warden',
#  'conf `` format `` warden',
#  'conf `` following `` `` url `` `` https //example',
#  'com/warden3 `` `` certfile `` `` cert',
#  'pem `` `` keyfile `` `` key',
#  'pem `` `` cafile `` `` /etc/ssl/certs/DigiCert_Assured_ID_Root_CA',
#  'pem `` `` timeout `` `` errlog `` `` file `` `` output/warden_logs/warden',
#  'err `` `` level `` `` debug `` `` filelog `` `` file `` `` output/warden_logs/warden',
#  'log `` `` level `` `` warning `` `` name `` `` com',
#  'test `` `` get key certificate need run `` warden_apply',
#  'sh `` registered client_name password Full instructions https //warden',
#  'cz/en/index `` name `` key registered warden node name evidence causing alert exported warden server alert generated See difference alerts evidence https //stratospherelinuxips',
#  'io/en/develop/architecture',
#  'html Slips architecture section change often get alerts import warden server default Slips imports alerts every day change changing `` receive_delay `` value `` config/slips',
#  'conf `` Slips logs alerts `` output/alerts',
#  'json `` CESNET IDEA0 format https //idea',
#  'cz/en/index default Make sure DigiCert_Assured_ID_Root_CA somewhere accessible slips run slips root want leave `` /etc/ssl/certs/ `` Refer Detection modules section docs https //stratospherelinuxips',
#  'io/en/develop/detection_modules',
#  'html cesnet-sharing-module detailed instructions CESNET importing Logstash Slips logstash',
#  'conf file exports alerts',
#  'json given output file change output preference example elastic search stdout etc Text logs default output Slips stored `` output/ `` directory files alert',
#  'json IDEA0 format alerts',
#  'log human readable text format Minimal makefile Sphinx documentation set variables command line also environment first SPHINXOPTS SPHINXBUILD sphinx-build SOURCEDIR BUILDDIR _build Put first `` make `` without argument like `` make help `` help SPHINXBUILD -M help `` SOURCEDIR `` `` BUILDDIR `` SPHINXOPTS ',
#  'PHONY help Makefile Catch-all target route unknown targets Sphinx using new `` make mode `` option meant shortcut SPHINXOPTS Makefile SPHINXBUILD -M `` SOURCEDIR `` `` BUILDDIR `` SPHINXOPTS ECHO pushd ~dp0 REM Command file Sphinx documentation `` SPHINXBUILD `` == `` `` set SPHINXBUILD=sphinx-build set SOURCEDIR= set BUILDDIR=_build `` `` == `` `` goto help SPHINXBUILD NUL NUL errorlevel echo echo',
#  "The 'sphinx-build command found Make sure Sphinx echo",
#  "installed set SPHINXBUILD environment variable point full path 'sphinx-build executable Alternatively echo",
#  'may add Sphinx directory PATH echo echo',
#  "If n't Sphinx installed grab echo",
#  'http //sphinx-doc',
#  "org/ exit /b SPHINXBUILD -M SOURCEDIR BUILDDIR SPHINXOPTS goto end help SPHINXBUILD -M help SOURCEDIR BUILDDIR SPHINXOPTS end popd FAQ Slips starting slow docker Make sure 're running many containers time share kernel resources even though 're isolated Getting `` Illegal instruction `` error running slips tensorflow version 're using n't compatible architecture get `` Illegal instruction `` error slips terminate fix disable modules use tensorflow adding `` rnn-cc-detection flowmldetection `` `` disable `` key `` config/slips",
#  "conf `` Docker time syncs host add local /etc/localtime volume Slips Docker container using `` docker run -it -- rm -- net=host -- cap-add=NET_ADMIN -v /etc/localtime /etc/localtime ro -- name slips stratosphereips/slips latest `` Training Slips machine learning module retrained users done puttin slips training mode re-train machine learning models traffic default Slips includes already trained model data sometimes necessary adapt circumstances Slips module called 'flowmldetection module analyzes flows one formatted similarly conn",
#  'log Zeek file module enabled default testing mode module uses default SGDClassifier linear support vector machine SVM decision use SVM done algorithms used online learning extend current model new data re-train machine learning algorithm need following 1- Edit config/slips',
#  "conf file put Slips train mode Search word __train__ section __ flowmldetection __ uncomment __mode train__ comment __mode test__ look like flowmldetection mode used tell flowmldetection module flows received training label provided Parameters section mode train mode used training models test unknown data trained least 'Normal data data order test work mode test 2- Establish general label traffic want re-train support label per file Search parameters section choose type traffic send Slips Set label flows read normal malware directly option setting labels filter label normal label malicious label unknown edits run Slips usual type input example Zeek folder ",
#  'py -c config/slips',
#  'conf -f ~/my-computer-normal/ pcap file ',
#  'py -c config/slips',
#  'conf -f ~/my-computer-normal2',
#  'pcap 3- also malicious traffic first change label malicious config/slips',
#  'conf Set label flows read normal malware directly option setting labels filter label normal label malicious label unknown ',
#  'py -c config/slips',
#  'conf -f ~/my-computer-normal2',
#  'pcap edits run Slips usual type input example another pcap ',
#  'py -c config/slips',
#  'conf -f ~/malware1',
#  'pcap also run slips interface train directly data ',
#  'py -c config/slips',
#  'conf -i eth0 4- Finally use model put back __test__ mode configuration config/slips',
#  "conf flowmldetection mode used tell flowmldetection module flows received training label provided Parameters section mode train mode used training models test unknown data trained least 'Normal data data order test work mode test 5- Use slips normally files interfaces ",
#  'py -c config/slips',
#  'conf -i eth0 Flow Alerts module flow alerts several behavioral techniques detect attacks analyzing content flow alone detection techniques Long connections Successful SSH connections Connections without DNS resolution DNS resolutions IPs never used Connections unknown ports Data exfiltration Malicious JA3 hashes Connections port Multiple reconnection attempts Alerts Zeek Self-signed certs invalid certs port-scans address scans password guessing DGA Connection multiple ports Malicious SSL certificates Pastebin downloads Young domains Bad SMTP logins SMTP login bruteforce DNS ARPA Scans SSH version changing Incompatible CN Weird HTTP methods Non-SSL connections port Non-HTTP connections port Connection private IPs Connection private IPs outside current local network High entropy DNS TXT answers Devices changing IPs details detection follows Long Connections Detect connections long except multicast connections defualt connection considered long exceeds seconds Minutes threshold changed `` slips',
#  "conf `` changing value `` long_connection_threshold `` Connections without DNS resolution detect connections done without previous DNS resolution idea connection without DNS resolution slightly suspicious Slips runs capturing packets directly network device opposed example PCAP file detection ignore connections happen first minute operation Slips times Slips started computer already running many DNS connections already done waiting minutes decreases amount False Positives detection ignore certain IP addresses connection without DNS ok exceptions Private IPs Localhost IPs Reserved IPs including super broadcast IPv6 local-link IPs Multicast IPs Broadcast IPs private Well known organizations DNS resolutions well known orgs might done using DoH case slips n't know DNS resolution resolved domain wo n't dns",
#  "log simply ignore alerts type connected well known organizations particular Facebook Apple Google Twitter Microsoft Slips uses lists organizations information IPs IP ranges domains ASNs stored `` slips_files/organizations_info `` used check whether IP/domain flow belong known org Slips n't detect 'connection without DNS running interface except done instance IP check DoH section https //stratospherelinuxips",
#  'io/en/develop/detection_modules',
#  'html detect-doh docs info slips detects DoH Successful SSH connections Slips detects successful SSH connections using ways Using Zeek Zeek logs successful SSH connection ssh',
#  'log default bytes sent SSH connection bytes DNS resolutions without connection detect DNS resolutions connection done resolution without usage slightly suspicious domains excepted reverse DNS resolutions using in-addr',
#  'local domains wild card domain Subdomains cymru',
#  'com since used ipwhois library get ASN IP range Ignore WPAD domain Windows Ignore domains without TLD Chrome test domains Connection unknown ports Slips list known ports located `` slips_files/ports_info/ports_used_by_specific_orgs',
#  'csv `` also list ports belong specific organization `` slips_files/ports_info/ports_used_by_specific_orgs',
#  "csv `` example even though n't well known port Apple uses Apple Push Notification Service APNS port n't files considered unknown Slips Slips detect established connections unknown ports Rejected connections established detected reconnection attempts details check Multiple reconnections https //stratospherelinuxips",
#  'io/en/develop/flowalerts',
#  "html multiple-reconnection-attempts Data Upload Slips generates 'possible data upload alerts number uploaded bytes IP exceeds MBs timewindow period default See detailed explanation timewindows https //stratospherelinuxips",
#  'io/en/develop/architecture',
#  'html highlight=timewindows architecture number MBs modified changing value `` data_exfiltration_threshold `` `` slips',
#  'conf `` Slips also detects data upload IP uploads =100MBs IP connections Malicious JA3 JA3s hashes Slips uses JA3 hashes detect C C servers JA3s infected clients JA3 Slips shipped ’ zeek scripts add JA3 JA3s fingerprints SSL log files generated zeek Slips supports JA3 feeds addition different threat intelligence feeds JA3 feeds contain JA3 fingerprints identified malicious JA3 threat intelligence feed used Slips Abuse',
#  'ch JA3 feed add JA3 TI feeds `` ja3_feeds `` `` slips',
#  'conf `` Connections port significant rise number attacks listed Port Last year equated attacks ’ almost Slips detects connection port using protocol malicious Multiple reconnection attempts Multiple reconnection attempts Slips established flows reconnections destination IP destination port Zeek alerts default Slips depends Zeek detecting different behaviours example Self-signed certs invalid certs port-scans address scans password guessing Password guessing detected zeek failed ssh logins happen mins scans also detected Slips independently Zeek like ICMP sweeps vertical/horizontal portscans Check PING Sweeps https //stratospherelinuxips',
#  'io/en/develop/detection_modules',
#  'html ping-sweeps section info SMTP login bruteforce Slips alerts invalid SMTP login attempts occurs within Password Guessing Password guessing detected using ethods slips ',
#  ' Zeek engine failed ssh logins happen mins slips failed ssh logins happen tiemwindow DGA DNS server fails resolve domain responds back NXDOMAIN code detect DGA Slips count amount NXDOMAINs met DNS traffic source IP alert NXDOMAINs Every ',
#  ' etc slips generates evidence Connection multiple ports Slips encounters connection specific IP specific port scans previous connections looking connection to/from IP using different port alerts finding connections IP Malicious SSL certificates Slips uses SSL certificates sha1 hashes detect C C servers Slips supports SSL feeds shipped Abuse',
#  'ch feed malicious SSL hashes default add SSL feeds `` ssl_feeds `` `` slips',
#  'conf `` Pastebin downloads Slips detects downloads pastebin using SSL HTTP alerts downloaded file pastebin exceeds bytes value customized slips',
#  "conf changing `` pastebin_download_threshold `` Slips detects pastebin download SSL connection may take hours Young Domains Slips uses whois python library get creation date every domain met dns flows domain age days slips sets alert domains supported list supported TLDs '",
#  'work Bad SMTP logins Slips uses zeek detect SMTP connections zeek detects bad smtp login logs smtp',
#  'log slips reads file sets evidence SMTP bruteforce Slips detects SMTP bruteforce bad SMTP logins happen within seconds -- every generated evidence Slips gathers much info malicious IP prints alert instead alerts saying Detected SSL certificate validation failed certificate expired Destination IP Slips gathers hostname SNI rDNS available data IP get alert saying Detected SSL certificate validation failed certificate expired Destination IP GOOGLE US SNI rDNS prg03s01-in-f70',
#  'net DNS ARPA Scans Whenever slips sees new domain dns',
#  "log domain ends '",
#  "arpa ' slips keeps trach domain source IP made DNS request source IP seen ARPA queries within seconds slips generates ARPA scan detection SSH version changing Zeek logs used software software versions software",
#  'log slips knows file software used different IPs like whether SSH : CLIENT HTTP : BROWSER HTTP : SERVER slips detects SSH client SSH server stores IP SSH versions used database whenever slips sees IP using another SSH version compares stored SSH versions current SSH versions different slips generates alert Incompatible CN Zeek logs Certificate CN ssl',
#  'log slips enccounters cn claims belong Slips supported orgs Google Microsoft Apple Twitter Slips checks destination address destination server name belongs org slips generates alert Weird HTTP methods Slips uses zeek weird',
#  'log zeek logs weird HTTP methods seen http',
#  'log weird HTTP method slips detects well Non-SSL connections port Slips detects established connections port using HTTP using zeek conn',
#  "log flows slips finds flow using destination port 'service field conn",
#  "log n't set 'ssl alerts Non-HTTP connections port Slips detects established connections port using SSL using zeek conn",
#  "log flows slips finds flow using destination port 'service field conn",
#  "log n't set 'http alerts Connection private IPs Slips detects private IP connected another private IP threat level info skips alert DNS connection port UDP gateway Connection private IPs outside current local network Slips detects currently used local network alerts find connection to/from private IP n't belong example currently used local network slips sees forged packet going alert High entropy DNS TXT answers Slips check every DNS answer TXT record high entropy strings Encoded encrypted strings entropy higher equal detected using shannon entropy alerted slips entropy threshold changed slips",
#  'conf changing value `` entropy_threshold `` Devices changing IPs Slips stores MAC new IP sees conn',
#  'log every source address conn',
#  'log slips checks MAC used another IP alerts `` Device changing IPs `` Features Section contain list features detections listed flowalerts section https //stratospherelinuxips',
#  'io/en/develop/flowalerts',
#  'html detection modules https //stratospherelinuxips',
#  'io/en/develop/detection_modules',
#  'html detection-modules section brief description slips works Flow Alerts Module module flow alerts several behavioral techniques detect attacks analyzing content flow alone detection techniques Long connections Successful SSH connections Connections without DNS resolution DNS resolutions IPs never used Connections unknown ports Data exfiltration Malicious JA3 hashes Connections port Multiple reconnection attempts Alerts Zeek Self-signed certs invalid certs port-scans address scans password guessing DGA Connection multiple ports Malicious SSL certificates Young domains Bad SMTP logins SMTP login bruteforce DNS ARPA Scans Multiple SSH versions Incompatible CN Weird HTTP methods Non-SSL connections port Non-HTTP connections port Connection private IPs Connection private IPs outside current local network High entropy DNS TXT answers Devices changeing IPs SSH version changing details detection follows Long Connections Detect connections long except multicast connections defualt connection considered long exceeds seconds Minutes threshold changed `` config/slips',
#  'conf `` changing value `` long_connection_threshold `` Incompatible CN Zeek logs Certificate CN ssl',
#  'log slips enccounters cn claims belong Slips supported orgs Google Microsoft Apple Twitter Slips checks destination address destination server name belongs org slips generates alert High entropy DNS TXT answers Slips check every DNS answer TXT record high entropy strings Encoded encrypted strings entropy higher equal detected using shannon entropy alerted slips entropy threshold changed slips',
#  'conf changing value `` entropy_threshold `` Devices changing IPs Slips stores MAC new IP sees conn',
#  'log every source address conn',
#  "log slips checks MAC used another IP alerts `` Device changing IPs `` SMTP login bruteforce Slips alerts invalid SMTP login attempts occurs within Connection private IPs Slips detects private IP connected another private IP threat level info skips alert DNS connection port UDP gateway Connection private IPs outside current local network Slips detects currently used local network alerts find connection to/from private IP n't belong example currently used local network slips sees forged packet going alert Weird HTTP methods Slips uses zeek weird",
#  'log zeek logs weird HTTP methods seen http',
#  'log weird HTTP method slips detects well Non-SSL connections port Slips detects established connections port using HTTP using zeek conn',
#  "log flows slips finds flow using destination port 'service field conn",
#  "log n't set 'ssl alerts Non-HTTP connections port Slips detects established connections port using SSL using zeek conn",
#  "log flows slips finds flow using destination port 'service field conn",
#  "log n't set 'http alerts Connections without DNS resolution detect connections done without previous DNS resolution idea connection without DNS resolution slightly suspicious Slips runs capturing packets directly network device opposed example PCAP file detection ignore connections happen first minute operation Slips times Slips started computer already running many DNS connections already done waiting minutes decreases amount False Positives detection ignore certain IP addresses connection without DNS ok exceptions Private IPs Localhost IPs Reserved IPs including super broadcast IPv6 local-link IPs Multicast IPs Broadcast IPs private Well known organizations DNS resolutions well known orgs might done using DoH case slips n't know DNS resolution resolved domain wo n't dns",
#  "log simply ignore alerts time well known org facebook apple google twitter microsoft Slips uses lists organizations info IPs IP ranges domains ASNs stored `` slips_files/organizations_info `` check whether IP/domain flow belong known org Slips n't detect 'connection without DNS running interface except done instance IP check DoH section https //stratospherelinuxips",
#  'io/en/develop/detection_modules',
#  'html detect-doh docs info slips detects DoH Successful SSH connections Slips detects successful SSH connections using ways Using Zeek Zeek logs successful SSH connection ssh',
#  'log default bytes sent SSH connection bytes DNS resolutions without connection detect DNS resolutions connection done resolution without usage slightly suspicious domains excepted reverse DNS resolutions using in-addr',
#  'local domains wild card domain Subdomains cymru',
#  'com since used ipwhois library get ASN IP range Ignore WPAD domain Windows Ignore domains without TLD Chrome test domains Connection unknown ports Slips list known ports located `` slips_files/ports_info/ports_used_by_specific_orgs',
#  'csv `` also list ports belong specific organization `` slips_files/ports_info/ports_used_by_specific_orgs',
#  "csv `` example even though n't well known port Apple uses Apple Push Notification Service APNS port n't files considered unknown Slips Example Spyware uses custom ports hermit https //www",
#  "com/blog/hermit-spyware-discovery using ports Data exfiltration Slips generate 'possible data exfiltration alerts number uploaded files IP exceeds MBs number MBs modified editting value `` data_exfiltration_threshold `` `` config/slips",
#  'conf `` Malicious JA3 JA3s hashes Slips uses JA3 hashes detect C C servers JA3s infected clients JA3 Slips shipped ’ zeek scripts add JA3 JA3s fingerprints SSL log files generated zeek Slips supports JA3 feeds addition different threat intelligence feeds JA3 feeds contain JA3 fingerprints identified malicious JA3 threat intelligence feed used Slips Abuse',
#  'ch JA3 feed add JA3 TI feeds `` ja3_feeds `` `` config/slips',
#  'conf `` Connections port significant rise number attacks listed Port Last year equated attacks ’ almost Slips detects connection port using protocol malicious Multiple reconnection attempts Multiple reconnection attempts Slips established flows reconnections destination IP Zeek alerts default Slips depends Zeek detecting different behaviours example Self-signed certs invalid certs port-scans address scans password guessing scans also detected Slips independently Zeek like ICMP sweeps vertical/horizontal portscans Check section info todo DGA DNS server fails resolve domain responds back NXDOMAIN code detect DGA Slips count amount NXDOMAINs met DNS traffic source IP alert NXDOMAINs Every ',
#  ' etc slips generates evidence Connection multiple ports Slips encounters connection specific IP specific port scans previous connections looking connection to/from IP using different port alerts finding connections IP Malicious SSL certificates Slips uses SSL certificates sha1 hashes detect C C servers Slips supports SSL feeds shipped Abuse',
#  'ch feed malicious SSL hashes default add SSL feeds `` ssl_feeds `` `` config/slips',
#  "conf `` Young Domains Slips uses whois python library get creation date every domain met dns flows domain age days slips sets alert domains supported list supported TLDs '",
#  'work Bad SMTP logins Slips uses zeek detect SMTP connections zeek detects bad smtp login logs smtp',
#  'log slips reads file sets evidence SMTP bruteforce Slips detects SMTP bruteforce bad SMTP logins happen within seconds -- every generated evidence Slips gathers much info malicious IP prints alert instead alerts saying Detected SSL certificate validation failed certificate expired Destination IP Slips gathers hostname SNI rDNS available data IP get alert saying Detected SSL certificate validation failed certificate expired Destination IP GOOGLE US SNI rDNS prg03s01-in-f70',
#  'net DNS ARPA Scans Whenever slips sees new domain dns',
#  "log domain ends '",
#  "arpa ' slips keeps trach domain source IP made DNS request source IP seen ARPA queries within seconds slips generates ARPA scan detection SSH version changing Zeek logs used software software versions software",
#  'log slips knows file software used different IPs like whether SSH : CLIENT HTTP : BROWSER HTTP : SERVER slips detects SSH client SSH server stores IP SSH versions used database whenever slips sees IP using another SSH version compares stored SSH versions current SSH versions different slips generates alert Detection modules Slips behavioral-based IPS uses machine learning detect malicious behaviors network traffic modular software extended Slips run spawns several child processes manage I/O profile attackers run detection modules describe detection modules run traffic detect malicious behaviour Modules Python-based files allow developer extend functionality Slips process analyze data perform additional detections store data Redis modules consume Currently Slips following modules style table font-family arial sans-serif border-collapse collapse width td th border solid dddddd text-align left padding tr nth-child even background-color dddddd /style table tr th Module /th Description /th th Status /th /tr tr td ARP Detection /td td Finds ARP scans MITM ARP local networrk ',
#  ' td ✅ /td /tr tr td Exporting /td td Exports Slips alerts Slack servers STIX servers ',
#  ' /td td ✅ /td /tr tr td IP_Info /td td Finds Geolocation country ASN IP address ',
#  ' /td td ✅ /td /tr tr td CESNET /td td Send receive alerts warden servers ',
#  ' /td td ✅ /td /tr tr td RiskIQ /td td Finds information RiskIQ passive DNS domains downloads Threat Intelligence feed ',
#  ' td ✅ /td /tr tr td Update /td td Takes care downloading files used Slips need update stores checks ETags remote files know changed configured update file different frequency importantly updates Threat Intelligence feeds ',
#  ' /td td ✅ /td /tr tr td Threat Intelligence /td td Checks domain IP included Threat Intelligence feeds Domains include DNS requests DNS replies HTTP hostnames TLS SNI IPs include source destination IPs IPv4 IPv6 /td td ✅ /td /tr tr td https /td td training test RandomForest detect malicious https flows /td td ⏳ /td /tr tr td port scan detector /td td detects Horizontal Vertical port scans /td td ✅ /td /tr tr td timeline /td td creates timeline happened network based flows type data available /td td ✅ /td /tr tr td rnn-cc-detection /td td detects command control channels using recurrent neural network stratosphere behavioral letters /td td ✅ /td /tr tr td VirusTotal /td td module lookup IP address VirusTotal /td td ✅ /td /tr tr td flowalerts /td td Finds malicious behaviours analyzing flow detects self-signed certificates TLS certificates validation failed vertical port scans detected Zeek contrary detected Slips horizontal port scans detected Zeek contrary detected Slips password guessing SSH detected Zeek long connection successful ssh /td td ✅ /td /tr tr td leak_detector /td td module detect leaks data traffic using YARA rules /td td ✅ /td /tr tr td ARP /td td module check ARP attacks ARP traffic /td td ✅ /td /tr tr td http_analyzer /td td module analyze HTTP traffic ',
#  ' td ✅ /td /tr tr td blocking /td td Blocks alerted IPs Linux iptables Firewall ',
#  ' /td td ✅ /td /tr tr td flowmldetection /td td module detect malicious flows using machine learning /td td ✅ /td /tr /table Virustotal Module module used lookup IPs domains URLs virustotal use need add virustotal API key `` config/vt_api_key `` RiskIQ Module module used get different information passive DNS IoCs etc RiskIQ https //www',
#  'com/ use module RiskIQ email API key stored `` config/RiskIQ_credentials `` format file following `` example domain',
#  'com e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855 `` hash character API Key path file modified changing `` RiskIQ_credentials_path `` parameter `` config/slips',
#  'conf `` Leak Detection Module module runs pcaps uses YARA rules detect leaks add YARA rule `` modules/leak_detector/yara_rules/rules `` automatically compiled stored `` modules/leak_detector/yara_rules/compiled `` matched every pcap Blocking Module enable blocking slips start slips `` -p `` flag feature supported linux using iptables natively using docker Exporting Alerts Module Slips supports exporting alerts systems using different modules ExportingAlerts CESNET sharing etc supported systems Slack TAXII Servers STIX format Warden servers IDEA JSON format Logstash Refer exporting section docs https //stratospherelinuxips',
#  'io/en/develop/exporting',
#  'html detailed instructions export Flowalerts Module module responsible detecting malicious behaviours traffic Refer Flowalerts section docs https //stratospherelinuxips',
#  'io/en/develop/flowalerts',
#  'html detailed explanation Slips detects detects Disabled alerts Slips detections turned default configure alerts want enable/disable `` config/slips',
#  "conf `` Slips support disabling unwanted alerts simply add detection want disable `` disabled_detections `` list slips generate alerts type example disabled_detections MaliciousJA3 DataExfiltration SelfSignedCertificate Supported detections ARPScan ARP-outside-localnet UnsolicitedARP MITM-ARP-attack SSHSuccessful LongConnection MultipleReconnectionAttempts ConnectionToMultiplePorts InvalidCertificate UnknownPort Port0Connection ConnectionWithoutDNS DNSWithoutConnection MaliciousJA3 DataExfiltration SelfSignedCertificate PortScanType1 PortScanType2 Password_Guessing MaliciousFlow SuspiciousUserAgent multiple_google_connections NETWORK_gps_location_leaked Command-and-Control-channels-detection ThreatIntelligenceBlacklistDomain ThreatIntelligenceBlacklistIP MaliciousDownloadedFile DGA MaliciousSSLCert YoungDomain MultipleSSHVersions DNS-ARPA-Scan SMTPLoginBruteforce BadSMTPLogin IncompatibleUserAgent ICMP-Timestamp-Scan ICMP-AddressScan ICMP-AddressMaskScan Threat Intelligence Module Slips complex system deal Threat Intelligence feeds Slips supports different kinds IoCs TI feeds IPs IP ranges domains JA3 hashes SSL hashes File hashes URLs n't supported Matching IPs Slips gets every IP find network tries see blacklist match found generates evidence exact match found searches Blacklisted ranges taken different TI feeds Matching Domains Slips gets every domain find network tries see blacklist domains currently taken DNS requests DNS responses HTTP host names TLS SNI domain found verified downloaded list domains blacklists defined `` ti_files `` configuration file `` config/slips",
#  'conf `` exact match found evidence generated exact match found Slips verifies verified domain subdomain domain blacklist example domain traffic _here',
#  'com_ Slips first checks exact domain _here',
#  'com_ blacklist match checks domain _testing',
#  'com_ blacklists Matching JA3 Hashes Every time Slips encounters TLS flow compares JA3 JA3s feeds malicious JA3 alerts ’ match Slips shipped Abuse',
#  'ch JA3 feed default add SSL feed appending file defined `` ja3_feeds `` key `` config/slips',
#  'conf `` default `` config/JA3_feeds',
#  'csv `` Matching SSL SHA1 Hashes Every time Slips encounters SSL flow tries get certificate hash zeek ssl',
#  'log compares hash list blacklisted SSL certificates Slips shipped Abuse',
#  'ch SSL feed default add SSL feed appending file defined `` ssl_feeds `` key `` config/slips',
#  'conf `` default `` config/SSL_feeds',
#  'csv `` Local Threat Intelligence files Slips local file adding IoCs located `` config/local_data_files/own_malicious_iocs',
#  'csv `` default path changed changing `` download_path_for_local_threat_intelligence `` `` config/slips',
#  'conf `` format file `` IP address `` `` Threat level `` `` Description `` Threat level available options info low medium high critical Refer architecture section docs https //stratospherelinuxips',
#  'io/en/develop/architecture',
#  'html detailed explanation Slips threat levels Example `` `` `` high `` `` Simda CC `` `` bncv00',
#  'info `` `` critical `` `` Variant',
#  'Zusy `` Local JA3 hashes Slips local file adding JA3 hashes located `` config/local_data_files/own_malicious_JA3',
#  'csv `` default format file `` JA3 hash `` `` Threat level `` `` Description `` Threat level available options info low medium high critical Refer architecture section docs https //stratospherelinuxips',
#  'io/en/develop/architecture',
#  'html detailed explanation Slips threat levels Example `` e7d705a3286e19ea42f587b344ee6865 `` `` medium `` `` Standard tor client `` `` `` `` high `` `` Trickbot Malwar `` Adding remote feed update remote ones regularly list remote threat intelligence files set variables `` ti_files `` variable config/slips',
#  'conf add remote threat intelligence feeds variable Supported extensions ',
#  'netset ipsum feeds ',
#  'intel URL added threat_level tag format url threat_level tag tag category feed e',
#  'g phishing adtrackers etc ',
#  ' Threat level available options info low medium high critical Refer architecture section docs https //stratospherelinuxips',
#  'io/en/develop/architecture',
#  "html detailed explanation Slips threat levels TI files commented using may processed 're still database Use `` `` commenting TI files `` config/slips",
#  'conf `` instead `` `` Commented TI files lines starting completely removed database remote files downloaded path set `` download_path_for_local_threat_intelligence `` default files stored Slips directory `` modules/ThreatIntelligence1/remote_data_files/ `` Commenting remote TI feed remote file link wish comment remove database adding line contains feed link `` config/slips',
#  "conf `` n't use example comment `` bruteforcelogin `` feed following https //lists",
#  'de/lists/bruteforcelogin',
#  "txt medium 'honeypot instead https //lists",
# ...
#  'io/en/develop/architecture',
#  'html detailed explanation Slips threat levels Example `` e7d705a3286e19ea42f587b344ee6865 `` `` medium `` `` Standard tor client `` `` `` `` high `` `` Trickbot Malwar `` Adding remote feed update remote ones regularly list remote threat intelligence files set path `` ti_files `` variable `` config/slips',
#  'conf `` path TI feeds `` config/TI_feeds',
#  'csv `` default add remote threat intelligence feeds variable Supported extensions ',
#  'netset ipsum feeds ',
#  'intel URL added threat_level tag format url threat_level tag tag category feed e',
#  'g phishing adtrackers etc ',
#  ' Threat level available options info low medium high critical Refer architecture section docs https //stratospherelinuxips',
#  'io/en/develop/architecture',
#  "html detailed explanation Slips threat levels TI files commented using may processed 're still database Use `` `` commenting TI files `` config/slips",
#  'conf `` instead `` `` Commented TI files lines starting completely removed database remote files downloaded path set `` download_path_for_local_threat_intelligence `` default files stored Slips directory `` modules/ThreatIntelligence1/remote_data_files/ `` deleted slips done reading Commenting remote TI feed remote file link wish comment remove database adding line contains feed link `` config/TI_feeds',
#  "csv `` n't use example comment `` bruteforcelogin `` feed following https //lists",
#  'de/lists/bruteforcelogin',
#  "txt medium 'honeypot instead https //lists",
#  'de/lists/bruteforcelogin',
#  'txt medium Update Manager Module make sure Slips date recent IoCs feeds feeds loaded parsed updated periodically automatically Slips every hours requires user interaction hours interval changed changing `` TI_files_update_period `` key `` config/slips',
#  'conf `` Update manager responsible updating remote TI files including SSL JA3 etc default local slips files organization_info ports_info etc cached avoid loading parsing everytime start slips However updated automatically update manager changed disk slips instance allowed using update manager time avoid race conditions IP Info Module IP info module several ways getting information IP address includes ASN Country Geolocation Given MAC Vendor Reverse DNS ASN Slips shipped offline database GeoLite2 `` databases/GeoLite2-ASN',
#  'mmdb `` search ASNs ASN given IP GeoLite2 database try get ASN online using online database using `` ipwhois `` library However reduce amount requests retrieve range IP cache whole range search cache whole range IP module uses ipwhois library ipwhois library gets range IP making connection server `` cymru',
#  'com `` using TXT DNS query DNS server set operating system example get ASN IP see DNS connection asking TXT record domain `` `` Country Geolocation Slips shipped offline database GeoLite2 `` databases/GeoLite2-Country',
#  'mmdb `` search Geolocation Mac Vendors Slips shipped offline database `` databases/macaddress-db',
#  'json `` MAC address vendor mapping Slips updates database default every weeks using following online db https //maclookup',
#  'app/downloads/json-database/get-db t=22-08-19 h=d1d39c52de447a7e7194331f379e1e99f94f35f1 change often db updated changing value `` mac_db_update `` `` config/slips',
#  'conf `` Slips gets MAC address IP dhcp',
#  "log searches offline database using OUI vendor n't found offline MAC database Slips tries get MAc using online database https //www",
#  'macvendorlookup',
#  "com offline database updated manually shipped slips find `` databases/ `` dir Slips makes sure n't perform duplicate searches MAC Address online offline Reverse DNS obtained standard in-addr",
#  "arpa DNS request ARP Module module used check ARP attacks network traffic default zeek n't generate log ARP flows Slips shipped zeek scripts enable logging ARP flows `` arp",
#  "log `` detection techniques ARP scans ARP destination IP outside local network Unsolicited ARP MITM ARP attack ARP Scans Slips considers IP performing ARP scan sends non-gratuitous ARP different destination addresses seconds less ARP destination IP outside local network Slips alerts ARP flow sent IP outside local network weird behaviour n't happening Unsolicited ARP Unsolicited ARP used update neighbours ARP caches also used ARP spoofing detect threat level 'info n't consider malicious simply notify MITM ARP attack Slips detects MAC IP trying tell others MAC also IP B ARP cache attack CESNET sharing Module module responsible importing exporting alerts warden server Refer exporting section docs https //stratospherelinuxips",
#  'io/en/develop/exporting',
#  'html detailed instructions CESNET exporting format configuration files enable importing alerts warden servers set `` receive_alerts `` `` yes `` config/slips',
#  'conf Slips imports alerts warden servers day automatically stores IoCs database Time wait receiving alerts warden server day default change chaning `` receive_delay `` `` config/slips',
#  "conf `` categories Slips imports 'Information 'Information HTTP Analyzer Module module handles detections HTTP flows Available detection Multiple empty connections Suspicious user agents Incompatible user agents Multiple user agents Pastebin downloads Unencrypted HTTP traffic Multiple empty connections Due usage empty connections popular site malware check internet connectivity consider type behaviour suspicious activity n't happen detect empty connection 'yahoo",
#  "com etc Suspicious user agents Slips list suspicious user agents whenever found traffic slips generates evidence current list user agents 'httpsend 'pb Incompatible user agents Slips uses offline MAC address database detect type device based MAC OUI First Slips store MAC address vendor every IP sees available Second slips encounters user agent HTTP traffic performs online query http //useragentstring",
#  "com get info user agent like os type name browser Third slips information available MAC vendor user agent compares detect incompatibility using list keywords operating system Available keywords Apple 'ios x 'macintosh Available keywords Microsoft 'windows Available keywords Android Multiple user agents Slips stores MAC address vendor every IP sees available redis database IP iss seen using different user agent stored database tries extract os info user agent string performing online query http //useragentstring",
#  "com using zeek IP detected using different user agents refer different operating systems alert type user agents made example IP detected using macOS user agent android user agent slips detects 'low threat level Pastebin downloads malware use pastebin host malicious payloads Slips detects downloads files pastebin HTTP size bytes value customized slips",
#  'conf changing `` pastebin_download_threshold `` found slips alerts pastebin download threat level low downloads pastebin malicious Unencrypted HTTP traffic slip sees HTTP unencrypted traffic zeek http',
#  'log generates evidence threat_level low Leak Detector Module module work slips given PCAP leak detector module uses YARA rules detect leaks PCAPs Module requirements order module run need ul li YARA installed compiled machine /li li yara-python /li li tshark /li /ul using `` sudo apt install yara `` install tshark running sudo apt install wireshark works module works Compiling YARA rules `` modules/leak_detector/yara_rules/rules/ `` directory Saving compiled rules `` modules/leak_detector/yara_rules/compiled/ `` Running compiled rules given PCAP find match get packet containing match set evidence Extending extend module adding YARA rules `` modules/leak_detector/yara_rules/rules/ `` rules automatically detected compiled run given PCAP want contribute improve existing Slips detection modules implement detection modules see section doc Contributing contributing Network Service Discovery Module module responsible detecting scans Vertical port scans Horizontal port scans PING sweeps DHCP Scans Vertical port scans Slips considers IP performing vertical port scan contacts different destination ports destination IP least time window usually flows TCP UDP Established Established arriving flow check performed detecting vertical port scan first time Slips detects new flows destination ports triggers waiting process find many packets new ports arrive waits seconds see flows arrive since port scans attcker scan ports avoids generating alert scan per flow long scan Therfore Slips wait scan finishes alert However first portscan detected soon happens analysts knows alert generated Slips waited seconds flows arrived new ports dst IP counter resets attacker needs _again_ threshold destinations ports IP detected avoids problem flows generated alert flow also generates alert total number _packets_ flows scan give confidence scan Horizontal port scans Slips considers IP performing horizontal port scan contacted destination IPs specific port established connections Slips checks TCP UDP connections horizontal port scans initial threshold destination IPs using destination ports detecting horizontal port scan Slips waits seconds see flows arrive since port scans attcker scan ports avoids generating port scan alert per flow long scan Therfore Slips wait scan finishes alert However first portscan detected soon happens analysts knows alert generated Slips waited seconds flows arrived new IPs counter resets attacker needs _again_ threshold destinations IPs port detected avoids problem flows generated alert flow also generates alert Slips ignores broadcast IP destination port scans PING Sweeps ICMP messages used find hosts alive network Slips relies Zeek detections done Zeek scripts located zeek-scripts/icmps-scans',
#  "zeek scripts detects types ICMP scans 'ICMP-Timestamp 'ICMP-Address 'ICMP-AddressMask detect scan every threshold generate evidence ",
#  ' etc ICMP established connections different IPs Slips detection using Slips zeek script located zeek-scripts/icmps-scans',
#  'zeek zeek pcap files using portscan module binetflow files DHCP Scans DHCP requests used find IPs taken network Slips detects IP requesting etc different IPs DHCP server within twimewindow hour default Connections Made Slips Slips uses online databases query information many different things example user agents mac vendors etc list contains connections made Slips useragentstring',
#  'com getting user agent info info found Zeek macvendorlookup',
#  'com getting MAC vendor info info found local maxmind db maclookup',
#  'app getting MAC vendor info info found local maxmind db ip-api',
#  'com getting ASN info IPs info found Redis DB ipinfo',
#  'io getting public IP virustotal',
#  'com getting scores domains IPs URLs urlhaus-api',
#  'ch getting info URLs downloaded files check',
#  'org getting info tor exist nodes cert',
#  'pl Used list TI files abuse',
#  'ch Used urlhaus getting info contacted domains downloaded files -- want contribute improve existing Slips detection modules implement detection modules see section doc Contributing contributing Zeek Scripts Slips shipped custom zeek scripts able extend zeek functionality customize detections Detect DoH `` detect_DoH',
#  "zeek `` script slips list ips belong dns/doh servers slips encouters connection IP list port assumes DoH connetion times connection connection wo n't take long appear slips Detect ICMP Scans `` zeek-scripts/icmps-scans",
#  'zeek `` script check type ICMP every ICMP packet seen network detect types ICMP scans ICMP-Timestamp-Scan ICMP-AddressScan ICMP-AddressMaskScan based icmp type detect scan every threshold generate evidence ',
#  ' etc ICMP established connections different IPs Detect Gateway address `` zeek-scripts/log_gw',
#  'zeek `` script responsible recognizing gateway address using zeek logging notice',
#  'log Architecture architecture Slips basically receive data input process common format enrich gather possible info IPs/MAC/User-Agents etc apply detection modules output results Slips heavily based Zeek monitoring tool input tool packets interface pcap file due excelent recognition protocols easiness identify content traffic Figure shows data analyzed Slips see Slips internally uses href= `` https //zeek',
#  'org/ `` Zeek /a open source network security monitoring tool Slips divides flows profiles profile timewindows Slips runs detection modules flow stores evidence alerts features appropriate profile structure data i',
#  'e zeek flows performed detections profiles timewindows data stored inside href= `` https //redis',
#  'io/ `` Redis /a database output Slips folder logs output/ directory alert',
#  'log Kalipso terminal graphical user interface Web interface style ',
#  'zoom transition transform ',
#  '2s Animation margin position relative z-index:999 ',
#  'zoom hover transform scale zoom /style div class= `` zoom `` img src= `` https //raw',
#  'githubusercontent',
#  'com/stratosphereips/StratosphereLinuxIPS/develop/docs/images/slips_internal_architecture',
#  'jpg `` title= `` Figure analysis network traffic Slips `` figcaption b Figure ',
#  ' /b analysis network traffic Slips input internal structure output ',
#  " /figcaption /div br explanation internal representation data usage Zeek usage Redis inside Slips Internal representation data Slips works flow level instead packet level gaining high level view behaviors Slips creates traffic profiles IP appears traffic profile contains complete behavior IP address profile divided time windows time window hour long default contains dozens features computed connections start time window Detections done time window allowing profile marked uninfected next time window Alerts vs Evidence running Slips alerts see red CLI bottom kalispo bunch evidence Evidence slips detections caused specific IP specific timeframe Slips n't alert every evidence/detection accumulates evidence generates alert amount gathered evidence crosses threshold threshold Slips generates alert marks timewindow malicious displays red kalipso blocks IP causing alert Usage Zeek Slips uses Zeek generate files input types data used create profiles example Slips uses data create visual timeline activities time window timeline consists Zeek generated flows additional interpretation logs like dns log http log Usage Redis database data inside Slips stored Redis in-memory data structure Redis allows modules Slips access data parallel Apart read write operations Slips takes advantage Redis messaging system called Redis PUB/SUB Processes may publish data channels others subscribe channels process new data published Threat Levels Slips threat levels style type= `` text/css `` ",
#  'tg border-collapse collapse border-spacing:0 ',
#  'tg td border-color black border-style solid border-width:1px font-family Arial sans-serif font-size:14px overflow hidden padding:10px word-break normal ',
#  'tg th border-color black border-style solid border-width:1px font-family Arial sans-serif font-size:14px font-weight normal overflow hidden padding:10px word-break normal ',
#  "tg-0pky border-color inherit text-align left vertical-align top /style table class= `` tg `` thead tr th class= `` tg-0pky `` span style= `` font-weight bold `` Threat Level /span /th th class= `` tg-0pky `` span style= `` font-weight bold `` Description /span /th th class= `` tg-0pky `` span style= `` font-weight bold `` Example /span /th /tr /thead tbody tr td class= `` tg-0pky `` Info /td td class= `` tg-0pky `` Information nothing /td td class= `` tg-0pky `` SSH login /td /tr tr td class= `` tg-0pky `` Low /td td class= `` tg-0pky `` Interesting activity consider /td td class= `` tg-0pky `` DNS without connection /td /tr tr td class= `` tg-0pky `` Medium /td td class= `` tg-0pky `` Suspicious activity n't happen /td td class= `` tg-0pky `` PING Sweep /td /tr tr td class= `` tg-0pky `` High /td td class= `` tg-0pky `` Malicious activity /td td class= `` tg-0pky `` Password guessing /td /tr /tr tr td class= `` tg-0pky `` Critical /td td class= `` tg-0pky `` Critical security results direct block /td td class= `` tg-0pky `` Malicious downloaded Files /td /tr /tbody /table"]

# %%
len(filtered_sentences)
# Out:
# 749

# %%
filtered_sentences[0]
# Out:
# 'Contributing contributions welcomed thank taking time contribute project set guidelines contributing development Slips contribute Run Slips report bugs needed features suggest ideas Pull requests solved GitHub issue new feature Pull request new detection module Persistent Git Branches following git branches Slips repository permanent master contains stable version Slips new versions least month develop contains latest unstable version Slips also latest features new features based branch Naming Git branches Pull Requests keep Git history clean facilitate revision contributions ask branches follow concise namings branch-naming patterns follow contributing Slips author-bugfix- pull request branch contains bugfix author-docs- pull request branch contains documentation work author-enhance- pull request branch contains enhancement new feature improvement nonetheless author-feature- pull request branch contains new feature author-refactor- pull request branch contains code refactoring branch base contribution Slips general rule base contributions develop branch Creating pull request Commits Commits follow KISS principle thing well keep simple stupid Commit messages easily readable imperative style `` Fix memory leak '

# %% [markdown]
# #Training

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.27.4-py3-none-any.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 52.6 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 21.7 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 55.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.11.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.13.4 tokenizers-0.13.3 transformers-4.27.4

# %%
# !pip install sacremoses
# !pip install SentencePiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 kB 15.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: regex in /usr/local/lib/python3.9/dist-packages (from sacremoses) (2022.10.31)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from sacremoses) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from sacremoses) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from sacremoses) (1.2.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from sacremoses) (4.65.0)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895259 sha256=cbd9b7cadca5eb9d11a14d21d56824e3fbb182c29a6fff50f0cf33a766e126e4
#   Stored in directory: /root/.cache/pip/wheels/12/1c/3d/46cf06718d63a32ff798a89594b61e7f345ab6b36d909ce033
# Successfully built sacremoses
# Installing collected packages: sacremoses
# Successfully installed sacremoses-0.0.53
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting SentencePiece
#   Downloading sentencepiece-0.1.98-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 19.3 MB/s eta 0:00:00
# Installing collected packages: SentencePiece
# Successfully installed SentencePiece-0.1.98

# %%
from transformers import AutoTokenizer, AutoModelForMaskedLM
from transformers import BertTokenizer, BertForMaskedLM

tokenizer = AutoTokenizer.from_pretrained('bert-large-uncased')
model = BertForMaskedLM.from_pretrained('bert-large-uncased')
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-large-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
max_length = model.config.max_position_embeddings
print("The maximum input size supported by the model is:", max_length)
# Out:
# The maximum input size supported by the model is: 512

# %%
# filtered_sentences

# %%
import nltk
nltk.download('punkt')

new_filt_sentences = []

for sentence in filtered_sentences:
    if len(sentence) <= max_length:
        new_filt_sentences.append(sentence)
    else:
        # Split the long sentence into shorter sentences
        sub_sentences = nltk.sent_tokenize(sentence)
        for sub_sentence in sub_sentences:
            if len(sub_sentence) <= max_length:
                new_filt_sentences.append(sub_sentence)
            else:
                start = 0
                while start < len(sub_sentence):
                    end = start + max_length
                    if end > len(sub_sentence):
                        end = len(sub_sentence)
                    truncated_sub_sentence = sub_sentence[start:end]
                    new_filt_sentences.append(truncated_sub_sentence)
                    start = end
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
len(filtered_sentences)
# Out:
# 749

# %%
len(new_filt_sentences)
# Out:
# 825

# %%
cnt=0
for f in filtered_sentences: cnt+=len(f)
print(cnt)
cnt=0
for f in new_filt_sentences: cnt+=len(f)
print(cnt)
# Out:
# 128773
# 128756

# %%
cnt=0
for f in new_filt_sentences: 
    if(len(f)>max_length): cnt+=1
print(cnt)
# Out:
# 0

# %%
import torch

tokenized_data = [tokenizer.encode(text, add_special_tokens=True) for text in new_filt_sentences]

# %%
import random

# Mask a random percentage of tokens in each sequence
masked_data = []
for sequence in tokenized_data:
    masked_sequence = sequence.copy()
    num_masks = int(len(sequence) * 0.15)  # Mask 15% of the tokens
    indices = random.sample(range(1, len(sequence) - 1), num_masks)  # Exclude special tokens [CLS] and [SEP]
    for index in indices:
        if random.random() < 0.8:  # 80% of the time, replace the token with [MASK]
            masked_sequence[index] = tokenizer.mask_token_id
        elif random.random() < 0.5:  # 10% of the time, replace the token with a random token
            masked_sequence[index] = random.randint(0, len(tokenizer) - 1)
    masked_data.append(masked_sequence)

# %%
# Pad the sequences that are shorter than max_length
padded_data = []
for sequence in masked_data:
    if len(sequence) < max_length:
        sequence += [tokenizer.pad_token_id] * (max_length - len(sequence))
    padded_data.append(sequence)

# Convert the padded data to PyTorch tensors
input_ids = torch.tensor(padded_data)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# from transformers import AutoTokenizer, AutoModelForMaskedLM
# from transformers import BertTokenizer, BertForMaskedLM

# model_path = '/content/drive/MyDrive/model'

# # Load the model from the specified path
# tokenizer = AutoTokenizer.from_pretrained('bert-large-uncased')
# model = BertForMaskedLM.from_pretrained(model_path)

# %%
import torch
from transformers import BertTokenizer, BertForMaskedLM
from torch.optim import AdamW
from tqdm import tqdm
from torch.utils.data import DataLoader

# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Define the optimizer
optimizer = AdamW(model.parameters(), lr=5e-5)

# Define the dataset
class TextDataset(torch.utils.data.Dataset):
    def __init__(self, input_ids):
        self.input_ids = input_ids
    
    def __len__(self):
        return len(self.input_ids)
    
    def __getitem__(self, index):
        return self.input_ids[index]

# Split the input ids into batches
batch_size = 7
input_ids = torch.tensor(input_ids)  # convert to tensor if it's not already
dataset = TextDataset(input_ids)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

epochs=3
# Loop through the data by batch
for epoch in range(epochs):
    for batch in tqdm(dataloader):  # Add tqdm to loop for progress bar
        batch = batch.to(device)  # Move the batch to the GPU

        # Set 15% of tokens to be masked
        mask_indices = torch.bernoulli(torch.full(batch.shape, 0.15)).bool()
        batch[mask_indices] = tokenizer.mask_token_id

        # Set another 15% of tokens to be randomly replaced
        random_indices = torch.bernoulli(torch.full(batch.shape, 0.15)).bool() & ~mask_indices
        random_tokens = torch.randint(len(tokenizer), batch.shape, dtype=torch.long).to(device)  # Move to the GPU
        batch[random_indices] = random_tokens[random_indices]

        # Clear gradients and compute forward pass
        optimizer.zero_grad()
        loss = model(input_ids=batch, labels=batch)[0]

        # Backpropagate the loss and update the weights
        loss.backward()
        optimizer.step()

    #Test after each epoch
    # Ask a question
    question = "install"
    question_tokens = tokenizer.tokenize(question)
    question_ids = torch.tensor([tokenizer.convert_tokens_to_ids(question_tokens)])

    # Move question_ids to the GPU
    question_ids = question_ids.to(device)

    # Get the model's predictions for the question
    with torch.no_grad():
        outputs = model(input_ids=question_ids)
        predictions = outputs[0]

    # Get the predicted tokens for the next k tokens after the masked token
    k = 15
    predicted_indices = torch.argsort(predictions[0, -1], descending=True)[:k]
    predicted_tokens = tokenizer.convert_ids_to_tokens(predicted_indices)

    # Print the question and predicted answers
    print("Question:", question)
    print("Top-{} predicted answers:".format(k))
    print(predicted_tokens)
# Out:
# <ipython-input-33-8c0b9769bfc0>:27: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   input_ids = torch.tensor(input_ids)  # convert to tensor if it's not already
# 100%|██████████| 118/118 [04:44<00:00,  2.41s/it]
# Question: install
# Top-15 predicted answers:
# ['##dm', '##hari', '##hmi', '##igan', '##chel', '##yst', '##tri', '##hore', '##tray', '##tyn', '##combe', '##hman', 'pleistocene', '##dai', '##lot']
# 100%|██████████| 118/118 [04:45<00:00,  2.42s/it]
# Question: install
# Top-15 predicted answers:
# ['##edly', '##planes', '##icides', '##inatory', '##tropical', '##ᵀ', '##hyllum', 'wealthiest', '##partisan', '##ocene', '##tively', '##nidae', '##quitable', '##ieving', 'townland']
# 100%|██████████| 118/118 [04:44<00:00,  2.41s/it]
# Question: install
# Top-15 predicted answers:
# ['##edly', '##planes', '##icides', '##inatory', '##ᵀ', '##tropical', 'wealthiest', '##partisan', '##hyllum', '##ocene', '##nidae', '##tively', '##quitable', 'townland', '##ieving']

# %%
# Replace <model_path> with the path where you want to save the model
model_path = '/content/drive/MyDrive/model'

# Save the model to the specified path
model.save_pretrained(model_path)

# %%
####TRAIN MORE

# # Define the optimizer
# optimizer = AdamW(model.parameters(), lr=e-3)

# # Split the input ids into batches
# batch_size = 16
# input_ids = torch.tensor(input_ids)  # convert to tensor if it's not already
# dataset = TextDataset(input_ids)
# dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# epochs=3
# # Loop through the data by batch
# for epoch in range(epochs):
#     for batch in tqdm(dataloader):  # Add tqdm to loop for progress bar
#         batch = batch.to(device)  # Move the batch to the GPU

#         # Set 15% of tokens to be masked
#         mask_indices = torch.bernoulli(torch.full(batch.shape, 0.15)).bool()
#         batch[mask_indices] = tokenizer.mask_token_id

#         # Set another 15% of tokens to be randomly replaced
#         random_indices = torch.bernoulli(torch.full(batch.shape, 0.15)).bool() & ~mask_indices
#         random_tokens = torch.randint(len(tokenizer), batch.shape, dtype=torch.long).to(device)  # Move to the GPU
#         batch[random_indices] = random_tokens[random_indices]

#         # Clear gradients and compute forward pass
#         optimizer.zero_grad()
#         loss = model(input_ids=batch, labels=batch)[0]

#         # Backpropagate the loss and update the weights
#         loss.backward()
#         optimizer.step()
#     # Ask a question
#     question = "install"
#     question_tokens = tokenizer.tokenize(question)
#     question_ids = torch.tensor([tokenizer.convert_tokens_to_ids(question_tokens)])

#     # Move question_ids to the GPU
#     question_ids = question_ids.to(device)

#     # Get the model's predictions for the question
#     with torch.no_grad():
#         outputs = model(input_ids=question_ids)
#         predictions = outputs[0]

#     # Get the predicted tokens for the next k tokens after the masked token
#     k = 15
#     predicted_indices = torch.argsort(predictions[0, -1], descending=True)[:k]
#     predicted_tokens = tokenizer.convert_ids_to_tokens(predicted_indices)

#     # Print the question and predicted answers
#     print("Question:", question)
#     print("Top-{} predicted answers:".format(k))
#     print(predicted_tokens)

# %%
# Ask a question
question = "Slips install"
question_tokens = tokenizer.tokenize(question)
question_ids = torch.tensor([tokenizer.convert_tokens_to_ids(question_tokens)])

# Move question_ids to the GPU
question_ids = question_ids.to(device)

# Get the model's predictions for the question
with torch.no_grad():
    outputs = model(input_ids=question_ids)
    predictions = outputs[0]

# Get the predicted tokens for the next k tokens after the masked token
k = 2
predicted_indices = torch.argsort(predictions[0, -1], descending=True)[:k]
predicted_tokens = tokenizer.convert_ids_to_tokens(predicted_indices)

# Print the question and predicted answers
print("Question:", question)
print("Top-{} predicted answers:".format(k))
print(predicted_tokens)
# Out:
# Question: Slips install
# Top-2 predicted answers:
# ['##edly', '##planes']
